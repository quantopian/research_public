# %% [markdown]
# # Fundamental factor models
#
# By Evgenia "Jenny" Nitishinskaya, Delaney Granizo-Mackenzie, and Maxwell Margenot.
#
# Part of the Quantopian Lecture Series:
#
# * [www.quantopian.com/lectures](https://www.quantopian.com/lectures)
# * [github.com/quantopian/research_public](https://github.com/quantopian/research_public)
#
# Notebook released under the Creative Commons Attribution 4.0 License.
#
# ---
#
# Fundamentals are data having to do with the asset issuer, like the sector, size, and expenses of the company. We can use this data to build a linear factor model, expressing returns on any asset as
#
# $$R_t = a_t + b_{t1} F_1 + b_{t2} F_2 + \ldots + b_{tK} F_K + \epsilon_t$$
#
# There are two different approaches to computing the factors $F_j$, which represent the returns associated with some fundamental characteristics, and the factor sensitivities $b_{tj}$.

# %% [markdown]
# ##Approach 1: Portfolio Construction
#
# In the first, we start by representing each characteristic of interest by a portfolio: we sort all assets by that characteristic, then build the portfolio by going long the top quantile of assets and short the bottom quantile. The factor corresponding to this characteristic is the return on this portfolio. Then, the $b_{ij}$ are estimated for each asset $i$ by regressing over the historical values of $R_i$ and of the factors.
#
# We'll use the canonical Fama-French factors for this example, which are the returns of portfolios constructred based on fundamental factors.
#
# We start by getting the fundamentals data for all assets and constructing the portfolios for each characteristic:

# %% [markdown]
# Import some libraries.

# %%
import numpy as np
import pandas as pd
from quantopian.pipeline.data import Fundamentals
import statsmodels.api as sm
from statsmodels import regression
import matplotlib.pyplot as plt
import scipy.stats

# %% [markdown]
# Set the date range for which we want data.

# %%
start_date = '2011-1-1'
end_date = '2012-1-1'

# %% [markdown]
# ###Using the Pipeline API to Fetch Data
#
# The pipeline API is a very useful tool for factor analysis. We use it here to get data for our analysis. Specifically, we want the daily values of book to price ratio and market cap for every security. But we also do several other useful filtering steps which are detailed in code comments.

# %%
import numpy as np
from quantopian.pipeline import Pipeline
from quantopian.pipeline.data import Fundamentals
from quantopian.pipeline.data.builtin import USEquityPricing
from quantopian.pipeline.factors import CustomFactor, Returns

# Here's the raw data we need, everything else is derivative.

class MarketCap(CustomFactor):
    # Here's the data we need for this factor
    inputs = [Fundamentals.shares_outstanding, USEquityPricing.close]
    # Only need the most recent values for both series
    window_length = 1
    
    def compute(self, today, assets, out, shares, close_price):
        # Shares * price/share = total price = market cap
        out[:] = shares * close_price
        
        
class BookToPrice(CustomFactor):
    # pb = price to book, we'll need to take the reciprocal later3
    inputs = [Fundamentals.pb_ratio]
    window_length = 1
    
    def compute(self, today, assets, out, pb):
        out[:] = 1 / pb
        
def make_pipeline():
    """
    Create and return our pipeline.
    
    We break this piece of logic out into its own function to make it easier to
    test and modify in isolation.
    
    In particular, this function can be copy/pasted into research and run by itself.
    """
    pipe = Pipeline()

    # Add our factors to the pipeline
    market_cap = MarketCap()
    # Raw market cap and book to price data gets fed in here
    pipe.add(market_cap, "market_cap")
    book_to_price = BookToPrice()
    pipe.add(book_to_price, "book_to_price")
    
    # We also get daily returns
    returns = Returns(inputs=[USEquityPricing.close], window_length=2)
    pipe.add(returns, "returns")
    
    # We compute a daily rank of both factors, this is used in the next step,
    # which is computing portfolio membership.
    market_cap_rank = market_cap.rank()
    pipe.add(market_cap_rank, 'market_cap_rank')
    
    book_to_price_rank = book_to_price.rank()
    pipe.add(book_to_price_rank, 'book_to_price_rank')

    # Build Filters representing the top and bottom 1000 stocks by our combined ranking system.
    biggest = market_cap_rank.top(1000)
    smallest = market_cap_rank.bottom(1000)
    
    highpb = book_to_price_rank.top(1000)
    lowpb = book_to_price_rank.bottom(1000)
    
    # Don't return anything not in this set, as we don't need it.
    pipe.set_screen(biggest | smallest | highpb | lowpb)
    
    # Add the boolean flags we computed to the output data
    pipe.add(biggest, 'biggest')
    pipe.add(smallest, 'smallest')
    
    pipe.add(highpb, 'highpb')
    pipe.add(lowpb, 'lowpb')
    
    return pipe

# %% [markdown]
# Now we initialize the pipeline.

# %%
pipe = make_pipeline()

# %% [markdown]
# We can visualize the dependency graph of our data computations here.

# %%
pipe.show_graph('png')

# %% [markdown]
# This function will allow us to run the pipeline.

# %%
from quantopian.research import run_pipeline

# %% [markdown]
# Now let's actually run it and check out our results.

# %%
# This takes a few minutes.
results = run_pipeline(pipe, start_date, end_date)
results
# Out:
#                                                biggest  book_to_price  \
# 2011-01-03 00:00:00+00:00 Equity(2 [ARNC])        True       0.861772
#                           Equity(21 [AAME])      False       1.828822
#                           Equity(24 [AAPL])       True       0.183999
#                           Equity(37 [ABCW])      False       0.277500
#                           Equity(51 [ABL])       False       2.075981
#                           Equity(58 [SERV])      False       1.639076
#                           Equity(62 [ABT])        True       0.305998
#                           Equity(64 [ABX])        True       0.366703
#                           Equity(67 [ADSK])       True       0.179099
#                           Equity(76 [TAP])        True       0.831808
#                           Equity(88 [ACI])        True       0.392495
#                           Equity(100 [IEP])      False       1.065417
#                           Equity(106 [ACU])      False       0.867604
#                           Equity(107 [ACV])       True       0.384793
#                           Equity(112 [ACY])      False       1.449275
#                           Equity(114 [ADBE])      True       0.336101
#                           Equity(117 [AEY])      False       1.065417
#                           Equity(122 [ADI])       True       0.284398
#                           Equity(128 [ADM])       True       0.829119
#                           Equity(134 [SXCL])     False       1.086012
#                           Equity(154 [AEM])       True       0.283198
#                           Equity(157 [AEG])       True       2.917153
#                           Equity(161 [AEP])       True       0.787402
#                           Equity(166 [AES])       True       0.674809
#                           Equity(168 [AET])       True       0.843313
#                           Equity(185 [AFL])       True       0.417206
#                           Equity(197 [AGCO])      True       0.563412
#                           Equity(205 [AGN])       True       0.226799
#                           Equity(216 [HES])       True       0.645703
#                           Equity(225 [AHPI])     False       0.772022
# ...                                                ...            ...
# 2012-01-03 00:00:00+00:00 Equity(41919 [ORIG])   False       1.866368
#                           Equity(41978 [BLMT])   False       1.360174
#                           Equity(42000 [ASBB])   False       1.768659
#                           Equity(42023 [XYL])     True       0.386100
#                           Equity(42027 [UBNT])   False       0.044800
#                           Equity(42037 [ZLTQ])   False       0.244200
#                           Equity(42060 [LMOS])   False       0.161301
#                           Equity(42080 [BUR])    False       0.048900
#                           Equity(42091 [ACHC])   False       0.300996
#                           Equity(42112 [GEVA])   False       0.158200
#                           Equity(42118 [GRPN])    True       0.052900
#                           Equity(42125 [VAC])    False       1.952362
#                           Equity(42131 [IMPV])   False       0.100400
#                           Equity(42147 [NLNK])   False       0.253698
#                           Equity(42165 [INVN])   False       0.204801
#                           Equity(42173 [DLPH])    True       0.238698
#                           Equity(42175 [ANGI])   False       0.050000
#                           Equity(42176 [FBIO])   False       0.158200
#                           Equity(42181 [DDMG])   False       0.123000
#                           Equity(42183 [IMI])    False       0.221298
#                           Equity(42184 [MFRM])   False       0.001700
#                           Equity(42217 [TAS])    False       0.160100
#                           Equity(42230 [TRIP])   False       0.087200
#                           Equity(42251 [WPX])    False       1.586294
#                           Equity(42260 [JIVE])   False       0.153600
#                           Equity(42262 [GZT])    False       1.231375
#                           Equity(42263 [LPI])    False       0.267101
#                           Equity(42270 [KORS])   False       0.058100
#                           Equity(42275 [MCEP])   False       0.133899
#                           Equity(42277 [ZNGA])   False       0.257699
#
#                                                 book_to_price_rank highpb  \
# 2011-01-03 00:00:00+00:00 Equity(2 [ARNC])                  3692.0  False
#                           Equity(21 [AAME])                 4843.0   True
#                           Equity(24 [AAPL])                  641.0  False
#                           Equity(37 [ABCW])                 1093.0  False
#                           Equity(51 [ABL])                  4901.0   True
#                           Equity(58 [SERV])                 4772.0   True
#                           Equity(62 [ABT])                  1244.0  False
#                           Equity(64 [ABX])                  1577.0  False
#                           Equity(67 [ADSK])                  614.0  False
#                           Equity(76 [TAP])                  3601.0  False
#                           Equity(88 [ACI])                  1714.0  False
#                           Equity(100 [IEP])                 4184.0   True
#                           Equity(106 [ACU])                 3711.0  False
#                           Equity(107 [ACV])                 1677.0  False
#                           Equity(112 [ACY])                 4681.0   True
#                           Equity(114 [ADBE])                1408.0  False
#                           Equity(117 [AEY])                 4185.0   True
#                           Equity(122 [ADI])                 1127.0  False
#                           Equity(128 [ADM])                 3592.0  False
#                           Equity(134 [SXCL])                4225.0   True
#                           Equity(154 [AEM])                 1119.0  False
#                           Equity(157 [AEG])                 5022.0   True
#                           Equity(161 [AEP])                 3476.0  False
#                           Equity(166 [AES])                 3062.0  False
#                           Equity(168 [AET])                 3633.0  False
#                           Equity(185 [AFL])                 1880.0  False
#                           Equity(197 [AGCO])                2577.0  False
#                           Equity(205 [AGN])                  828.0  False
#                           Equity(216 [HES])                 2921.0  False
#                           Equity(225 [AHPI])                3426.0  False
# ...                                                            ...    ...
# 2012-01-03 00:00:00+00:00 Equity(41919 [ORIG])              4546.0   True
#                           Equity(41978 [BLMT])              4173.0   True
#                           Equity(42000 [ASBB])              4498.0   True
#                           Equity(42023 [XYL])               1396.0  False
#                           Equity(42027 [UBNT])               113.0  False
#                           Equity(42037 [ZLTQ])               762.0  False
#                           Equity(42060 [LMOS])               453.0  False
#                           Equity(42080 [BUR])                122.0  False
#                           Equity(42091 [ACHC])              1000.0  False
#                           Equity(42112 [GEVA])               438.0  False
#                           Equity(42118 [GRPN])               132.0  False
#                           Equity(42125 [VAC])               4579.0   True
#                           Equity(42131 [IMPV])               252.0  False
#                           Equity(42147 [NLNK])               806.0  False
#                           Equity(42165 [INVN])               611.0  False
#                           Equity(42173 [DLPH])               739.0  False
#                           Equity(42175 [ANGI])               125.0  False
#                           Equity(42176 [FBIO])               439.0  False
#                           Equity(42181 [DDMG])               327.0  False
#                           Equity(42183 [IMI])                672.0  False
#                           Equity(42184 [MFRM])                11.0  False
#                           Equity(42217 [TAS])                446.0  False
#                           Equity(42230 [TRIP])               214.0  False
#                           Equity(42251 [WPX])               4388.0   True
#                           Equity(42260 [JIVE])               428.0  False
#                           Equity(42262 [GZT])               4002.0   True
#                           Equity(42263 [LPI])                862.0  False
#                           Equity(42270 [KORS])               145.0  False
#                           Equity(42275 [MCEP])               367.0  False
#                           Equity(42277 [ZNGA])               823.0  False
#
#                                                 lowpb    market_cap  \
# 2011-01-03 00:00:00+00:00 Equity(2 [ARNC])      False  1.573939e+10
#                           Equity(21 [AAME])     False  4.520649e+07
#                           Equity(24 [AAPL])      True  2.957765e+11
#                           Equity(37 [ABCW])     False  2.601996e+07
#                           Equity(51 [ABL])      False  2.415793e+05
#                           Equity(58 [SERV])     False  8.785597e+06
#                           Equity(62 [ABT])      False  7.410642e+10
#                           Equity(64 [ABX])      False  5.297976e+10
#                           Equity(67 [ADSK])      True  8.684501e+09
#                           Equity(76 [TAP])      False  9.346527e+09
#                           Equity(88 [ACI])      False  5.696626e+09
#                           Equity(100 [IEP])     False  3.059537e+09
#                           Equity(106 [ACU])     False  2.914869e+07
#                           Equity(107 [ACV])     False  3.663792e+09
#                           Equity(112 [ACY])     False  2.793295e+07
#                           Equity(114 [ADBE])    False  1.565830e+10
#                           Equity(117 [AEY])     False  3.185207e+07
#                           Equity(122 [ADI])     False  1.125324e+10
#                           Equity(128 [ADM])     False  1.922430e+10
#                           Equity(134 [SXCL])    False           NaN
#                           Equity(154 [AEM])     False  1.285688e+10
#                           Equity(157 [AEG])     False  1.048098e+10
#                           Equity(161 [AEP])     False  1.728034e+10
#                           Equity(166 [AES])     False  9.602996e+09
#                           Equity(168 [AET])     False  1.221105e+10
#                           Equity(185 [AFL])     False  2.660742e+10
#                           Equity(197 [AGCO])    False  4.714629e+09
#                           Equity(205 [AGN])      True  2.085581e+10
#                           Equity(216 [HES])     False  2.515632e+10
#                           Equity(225 [AHPI])    False  3.480156e+07
# ...                                               ...           ...
# 2012-01-03 00:00:00+00:00 Equity(41919 [ORIG])  False  1.606703e+09
#                           Equity(41978 [BLMT])  False  9.668194e+07
#                           Equity(42000 [ASBB])  False  6.533925e+07
#                           Equity(42023 [XYL])   False  4.732386e+09
#                           Equity(42027 [UBNT])   True  1.665053e+09
#                           Equity(42037 [ZLTQ])   True  3.851130e+08
#                           Equity(42060 [LMOS])   True  3.223052e+08
#                           Equity(42080 [BUR])    True           NaN
#                           Equity(42091 [ACHC])   True  2.241216e+08
#                           Equity(42112 [GEVA])   True  4.661298e+08
#                           Equity(42118 [GRPN])   True  1.310048e+10
#                           Equity(42125 [VAC])   False           NaN
#                           Equity(42131 [IMPV])   True  7.691390e+08
#                           Equity(42147 [NLNK])   True  1.442798e+08
#                           Equity(42165 [INVN])   True  7.892607e+08
#                           Equity(42173 [DLPH])   True  7.070387e+09
#                           Equity(42175 [ANGI])   True  8.950786e+08
#                           Equity(42176 [FBIO])   True           NaN
#                           Equity(42181 [DDMG])   True  2.362159e+08
#                           Equity(42183 [IMI])    True  3.644519e+08
#                           Equity(42184 [MFRM])   True  7.648897e+08
#                           Equity(42217 [TAS])    True  9.025215e+07
#                           Equity(42230 [TRIP])   True           NaN
#                           Equity(42251 [WPX])   False           NaN
#                           Equity(42260 [JIVE])   True           NaN
#                           Equity(42262 [GZT])   False           NaN
#                           Equity(42263 [LPI])    True           NaN
#                           Equity(42270 [KORS])   True           NaN
#                           Equity(42275 [MCEP])   True           NaN
#                           Equity(42277 [ZNGA])   True           NaN
#
#                                                 market_cap_rank   returns  \
# 2011-01-03 00:00:00+00:00 Equity(2 [ARNC])               4632.0  0.013083
#                           Equity(21 [AAME])               706.0 -0.009756
#                           Equity(24 [AAPL])              4972.0 -0.003769
#                           Equity(37 [ABCW])               476.0  0.000000
#                           Equity(51 [ABL])                  5.0 -0.082353
#                           Equity(58 [SERV])               165.0  0.030172
#                           Equity(62 [ABT])               4896.0  0.007778
#                           Equity(64 [ABX])               4865.0  0.011217
#                           Equity(67 [ADSK])              4389.0 -0.014952
#                           Equity(76 [TAP])               4428.0 -0.004362
#                           Equity(88 [ACI])               4240.0 -0.005954
#                           Equity(100 [IEP])              3887.0  0.006853
#                           Equity(106 [ACU])               513.0 -0.003141
#                           Equity(107 [ACV])              4004.0 -0.000270
#                           Equity(112 [ACY])               499.0  0.008357
#                           Equity(114 [ADBE])             4630.0  0.006869
#                           Equity(117 [AEY])               543.0  0.000000
#                           Equity(122 [ADI])              4501.0 -0.007638
#                           Equity(128 [ADM])              4681.0  0.007028
#                           Equity(134 [SXCL])                NaN       NaN
#                           Equity(154 [AEM])              4557.0  0.002354
#                           Equity(157 [AEG])              4478.0  0.008210
#                           Equity(161 [AEP])              4659.0 -0.002495
#                           Equity(166 [AES])              4441.0 -0.002048
#                           Equity(168 [AET])              4532.0  0.002628
#                           Equity(185 [AFL])              4748.0  0.006238
#                           Equity(197 [AGCO])             4149.0 -0.002363
#                           Equity(205 [AGN])              4700.0  0.000000
#                           Equity(216 [HES])              4736.0  0.001308
#                           Equity(225 [AHPI])              586.0  0.004673
# ...                                                         ...       ...
# 2012-01-03 00:00:00+00:00 Equity(41919 [ORIG])           3418.0  0.019215
#                           Equity(41978 [BLMT])           1231.0 -0.001894
#                           Equity(42000 [ASBB])            991.0  0.003258
#                           Equity(42023 [XYL])            4137.0 -0.011565
#                           Equity(42027 [UBNT])           3449.0 -0.019397
#                           Equity(42037 [ZLTQ])           2278.0  0.030853
#                           Equity(42060 [LMOS])           2153.0  0.010575
#                           Equity(42080 [BUR])               NaN       NaN
#                           Equity(42091 [ACHC])           1847.0  0.012208
#                           Equity(42112 [GEVA])           2434.0 -0.007092
#                           Equity(42118 [GRPN])           4522.0 -0.037488
#                           Equity(42125 [VAC])               NaN  0.002335
#                           Equity(42131 [IMPV])           2872.0  0.019930
#                           Equity(42147 [NLNK])           1489.0 -0.009887
#                           Equity(42165 [INVN])           2893.0  0.001006
#                           Equity(42173 [DLPH])           4300.0  0.005602
#                           Equity(42175 [ANGI])           2994.0  0.006879
#                           Equity(42176 [FBIO])              NaN  0.083333
#                           Equity(42181 [DDMG])           1893.0 -0.029221
#                           Equity(42183 [IMI])            2235.0  0.010514
#                           Equity(42184 [MFRM])           2867.0  0.014880
#                           Equity(42217 [TAS])            1185.0  0.026667
#                           Equity(42230 [TRIP])              NaN  0.014481
#                           Equity(42251 [WPX])               NaN  0.004444
#                           Equity(42260 [JIVE])              NaN -0.011098
#                           Equity(42262 [GZT])               NaN  0.011777
#                           Equity(42263 [LPI])               NaN  0.058516
#                           Equity(42270 [KORS])              NaN -0.001834
#                           Equity(42275 [MCEP])              NaN  0.000000
#                           Equity(42277 [ZNGA])              NaN  0.001609
#
#                                                smallest
# 2011-01-03 00:00:00+00:00 Equity(2 [ARNC])        False
#                           Equity(21 [AAME])        True
#                           Equity(24 [AAPL])       False
#                           Equity(37 [ABCW])        True
#                           Equity(51 [ABL])         True
#                           Equity(58 [SERV])        True
#                           Equity(62 [ABT])        False
#                           Equity(64 [ABX])        False
#                           Equity(67 [ADSK])       False
#                           Equity(76 [TAP])        False
#                           Equity(88 [ACI])        False
#                           Equity(100 [IEP])       False
#                           Equity(106 [ACU])        True
#                           Equity(107 [ACV])       False
#                           Equity(112 [ACY])        True
#                           Equity(114 [ADBE])      False
#                           Equity(117 [AEY])        True
#                           Equity(122 [ADI])       False
#                           Equity(128 [ADM])       False
#                           Equity(134 [SXCL])      False
#                           Equity(154 [AEM])       False
#                           Equity(157 [AEG])       False
#                           Equity(161 [AEP])       False
#                           Equity(166 [AES])       False
#                           Equity(168 [AET])       False
#                           Equity(185 [AFL])       False
#                           Equity(197 [AGCO])      False
#                           Equity(205 [AGN])       False
#                           Equity(216 [HES])       False
#                           Equity(225 [AHPI])       True
# ...                                                 ...
# 2012-01-03 00:00:00+00:00 Equity(41919 [ORIG])    False
#                           Equity(41978 [BLMT])    False
#                           Equity(42000 [ASBB])     True
#                           Equity(42023 [XYL])     False
#                           Equity(42027 [UBNT])    False
#                           Equity(42037 [ZLTQ])    False
#                           Equity(42060 [LMOS])    False
#                           Equity(42080 [BUR])     False
#                           Equity(42091 [ACHC])    False
#                           Equity(42112 [GEVA])    False
#                           Equity(42118 [GRPN])    False
#                           Equity(42125 [VAC])     False
#                           Equity(42131 [IMPV])    False
#                           Equity(42147 [NLNK])    False
#                           Equity(42165 [INVN])    False
#                           Equity(42173 [DLPH])    False
#                           Equity(42175 [ANGI])    False
#                           Equity(42176 [FBIO])    False
#                           Equity(42181 [DDMG])    False
#                           Equity(42183 [IMI])     False
#                           Equity(42184 [MFRM])    False
#                           Equity(42217 [TAS])     False
#                           Equity(42230 [TRIP])    False
#                           Equity(42251 [WPX])     False
#                           Equity(42260 [JIVE])    False
#                           Equity(42262 [GZT])     False
#                           Equity(42263 [LPI])     False
#                           Equity(42270 [KORS])    False
#                           Equity(42275 [MCEP])    False
#                           Equity(42277 [ZNGA])    False
#
# [778729 rows x 9 columns]

# %% [markdown]
# Great, we have all the data. Now we need to compute the returns of our portfolios over time. We have the daily returns for each equity, plus whether or not that equity was included in any given portfolio on any given day. We can combine that information in the following way to yield daily portfolio returns.

# %% [markdown]
# Step 1: Subset our results into only data belonging to our 'biggest' portfolio.

# %%
results[results.biggest]
# Out:
#                                                biggest  book_to_price  \
# 2011-01-03 00:00:00+00:00 Equity(2 [ARNC])        True       0.861772
#                           Equity(24 [AAPL])       True       0.183999
#                           Equity(62 [ABT])        True       0.305998
#                           Equity(64 [ABX])        True       0.366703
#                           Equity(67 [ADSK])       True       0.179099
#                           Equity(76 [TAP])        True       0.831808
#                           Equity(88 [ACI])        True       0.392495
#                           Equity(107 [ACV])       True       0.384793
#                           Equity(114 [ADBE])      True       0.336101
#                           Equity(122 [ADI])       True       0.284398
#                           Equity(128 [ADM])       True       0.829119
#                           Equity(154 [AEM])       True       0.283198
#                           Equity(157 [AEG])       True       2.917153
#                           Equity(161 [AEP])       True       0.787402
#                           Equity(166 [AES])       True       0.674809
#                           Equity(168 [AET])       True       0.843313
#                           Equity(185 [AFL])       True       0.417206
#                           Equity(197 [AGCO])      True       0.563412
#                           Equity(205 [AGN])       True       0.226799
#                           Equity(216 [HES])       True       0.645703
#                           Equity(239 [AIG])       True       1.647718
#                           Equity(273 [ALU])       True       0.684885
#                           Equity(300 [ALK])       True       0.542800
#                           Equity(328 [ALTR])      True       0.204399
#                           Equity(337 [AMAT])      True       0.404008
#                           Equity(338 [BEAM])      True       0.613685
#                           Equity(351 [AMD])       True       0.181301
#                           Equity(353 [AME])       True       0.281397
#                           Equity(357 [TWX])       True       0.931706
#                           Equity(368 [AMGN])      True       0.467990
# ...                                                ...            ...
# 2012-01-03 00:00:00+00:00 Equity(39073 [CIE])     True       0.345698
#                           Equity(39095 [CHTR])    True       0.071400
#                           Equity(39347 [ST])      True       0.225301
#                           Equity(39495 [SDRL])    True       0.385104
#                           Equity(39499 [VEON])    True       0.916003
#                           Equity(39546 [LYB])     True       0.572705
#                           Equity(39612 [SIX])     True       0.338799
#                           Equity(39778 [QEP])     True       0.637308
#                           Equity(39843 [PACT])    True       0.051600
#                           Equity(39963 [WPZ])     True       0.576402
#                           Equity(39994 [NXPI])    True       0.295902
#                           Equity(40338 [SMFG])    True       1.660302
#                           Equity(40430 [GM])      True       0.874279
#                           Equity(40445 [LPLA])    True       0.407997
#                           Equity(40573 [FRC])     True       0.635809
#                           Equity(40616 [MMI])     True       0.434707
#                           Equity(40755 [NLSN])    True       0.433896
#                           Equity(40852 [KMI])     True       0.128500
#                           Equity(41047 [HCA])     True            NaN
#                           Equity(41150 [APO])     True       0.160800
#                           Equity(41242 [ARCO])    True       0.157801
#                           Equity(41416 [KOS])     True       0.213502
#                           Equity(41451 [LNKD])    True       0.097700
#                           Equity(41462 [MOS])     True       0.526704
#                           Equity(41484 [YNDX])    True       0.138101
#                           Equity(41636 [MPC])     True       0.799808
#                           Equity(41886 [FNV])     True       0.538097
#                           Equity(42023 [XYL])     True       0.386100
#                           Equity(42118 [GRPN])    True       0.052900
#                           Equity(42173 [DLPH])    True       0.238698
#
#                                                 book_to_price_rank highpb  \
# 2011-01-03 00:00:00+00:00 Equity(2 [ARNC])                  3692.0  False
#                           Equity(24 [AAPL])                  641.0  False
#                           Equity(62 [ABT])                  1244.0  False
#                           Equity(64 [ABX])                  1577.0  False
#                           Equity(67 [ADSK])                  614.0  False
#                           Equity(76 [TAP])                  3601.0  False
#                           Equity(88 [ACI])                  1714.0  False
#                           Equity(107 [ACV])                 1677.0  False
#                           Equity(114 [ADBE])                1408.0  False
#                           Equity(122 [ADI])                 1127.0  False
#                           Equity(128 [ADM])                 3592.0  False
#                           Equity(154 [AEM])                 1119.0  False
#                           Equity(157 [AEG])                 5022.0   True
#                           Equity(161 [AEP])                 3476.0  False
#                           Equity(166 [AES])                 3062.0  False
#                           Equity(168 [AET])                 3633.0  False
#                           Equity(185 [AFL])                 1880.0  False
#                           Equity(197 [AGCO])                2577.0  False
#                           Equity(205 [AGN])                  828.0  False
#                           Equity(216 [HES])                 2921.0  False
#                           Equity(239 [AIG])                 4774.0   True
#                           Equity(273 [ALU])                 3096.0  False
#                           Equity(300 [ALK])                 2500.0  False
#                           Equity(328 [ALTR])                 732.0  False
#                           Equity(337 [AMAT])                1799.0  False
#                           Equity(338 [BEAM])                2781.0  False
#                           Equity(351 [AMD])                  629.0  False
#                           Equity(353 [AME])                 1111.0  False
#                           Equity(357 [TWX])                 3880.0  False
#                           Equity(368 [AMGN])                2164.0  False
# ...                                                            ...    ...
# 2012-01-03 00:00:00+00:00 Equity(39073 [CIE])               1208.0  False
#                           Equity(39095 [CHTR])               179.0  False
#                           Equity(39347 [ST])                 688.0  False
#                           Equity(39495 [SDRL])              1391.0  False
#                           Equity(39499 [VEON])              3266.0  False
#                           Equity(39546 [LYB])               2176.0  False
#                           Equity(39612 [SIX])               1179.0  False
#                           Equity(39778 [QEP])               2412.0  False
#                           Equity(39843 [PACT])               130.0  False
#                           Equity(39963 [WPZ])               2193.0  False
#                           Equity(39994 [NXPI])               984.0  False
#                           Equity(40338 [SMFG])              4443.0   True
#                           Equity(40430 [GM])                3160.0  False
#                           Equity(40445 [LPLA])              1485.0  False
#                           Equity(40573 [FRC])               2405.0  False
#                           Equity(40616 [MMI])               1606.0  False
#                           Equity(40755 [NLSN])              1601.0  False
#                           Equity(40852 [KMI])                344.0  False
#                           Equity(41047 [HCA])                  NaN  False
#                           Equity(41150 [APO])                451.0  False
#                           Equity(41242 [ARCO])               435.0  False
#                           Equity(41416 [KOS])                642.0  False
#                           Equity(41451 [LNKD])               240.0  False
#                           Equity(41462 [MOS])               1995.0  False
#                           Equity(41484 [YNDX])               379.0  False
#                           Equity(41636 [MPC])               2945.0  False
#                           Equity(41886 [FNV])               2038.0  False
#                           Equity(42023 [XYL])               1396.0  False
#                           Equity(42118 [GRPN])               132.0  False
#                           Equity(42173 [DLPH])               739.0  False
#
#                                                 lowpb    market_cap  \
# 2011-01-03 00:00:00+00:00 Equity(2 [ARNC])      False  1.573939e+10
#                           Equity(24 [AAPL])      True  2.957765e+11
#                           Equity(62 [ABT])      False  7.410642e+10
#                           Equity(64 [ABX])      False  5.297976e+10
#                           Equity(67 [ADSK])      True  8.684501e+09
#                           Equity(76 [TAP])      False  9.346527e+09
#                           Equity(88 [ACI])      False  5.696626e+09
#                           Equity(107 [ACV])     False  3.663792e+09
#                           Equity(114 [ADBE])    False  1.565830e+10
#                           Equity(122 [ADI])     False  1.125324e+10
#                           Equity(128 [ADM])     False  1.922430e+10
#                           Equity(154 [AEM])     False  1.285688e+10
#                           Equity(157 [AEG])     False  1.048098e+10
#                           Equity(161 [AEP])     False  1.728034e+10
#                           Equity(166 [AES])     False  9.602996e+09
#                           Equity(168 [AET])     False  1.221105e+10
#                           Equity(185 [AFL])     False  2.660742e+10
#                           Equity(197 [AGCO])    False  4.714629e+09
#                           Equity(205 [AGN])      True  2.085581e+10
#                           Equity(216 [HES])     False  2.515632e+10
#                           Equity(239 [AIG])     False  7.789653e+09
#                           Equity(273 [ALU])     False  6.666987e+09
#                           Equity(300 [ALK])     False  4.179992e+09
#                           Equity(328 [ALTR])     True  1.112726e+10
#                           Equity(337 [AMAT])    False  1.864509e+10
#                           Equity(338 [BEAM])    False  9.196046e+09
#                           Equity(351 [AMD])      True  5.582953e+09
#                           Equity(353 [AME])     False  9.422931e+09
#                           Equity(357 [TWX])     False  3.569718e+10
#                           Equity(368 [AMGN])    False  5.187037e+10
# ...                                               ...           ...
# 2012-01-03 00:00:00+00:00 Equity(39073 [CIE])   False  6.074059e+09
#                           Equity(39095 [CHTR])   True  6.124364e+09
#                           Equity(39347 [ST])     True  4.627866e+09
#                           Equity(39495 [SDRL])  False  1.549370e+10
#                           Equity(39499 [VEON])  False  1.533978e+10
#                           Equity(39546 [LYB])   False  1.875530e+10
#                           Equity(39612 [SIX])   False  4.537145e+09
#                           Equity(39778 [QEP])   False  5.186478e+09
#                           Equity(39843 [PACT])   True  5.480267e+09
#                           Equity(39963 [WPZ])   False  4.003910e+09
#                           Equity(39994 [NXPI])   True  3.794163e+09
#                           Equity(40338 [SMFG])  False  3.888653e+10
#                           Equity(40430 [GM])    False  3.172775e+10
#                           Equity(40445 [LPLA])  False  3.370959e+09
#                           Equity(40573 [FRC])   False  3.962767e+09
#                           Equity(40616 [MMI])   False  1.161710e+10
#                           Equity(40755 [NLSN])  False  1.065822e+10
#                           Equity(40852 [KMI])    True  2.603238e+10
#                           Equity(41047 [HCA])   False  9.621723e+09
#                           Equity(41150 [APO])    True  4.505350e+09
#                           Equity(41242 [ARCO])   True  4.301639e+09
#                           Equity(41416 [KOS])    True  4.787568e+09
#                           Equity(41451 [LNKD])   True  6.066140e+09
#                           Equity(41462 [MOS])   False  2.252842e+10
#                           Equity(41484 [YNDX])   True  6.359126e+09
#                           Equity(41636 [MPC])   False  1.187206e+10
#                           Equity(41886 [FNV])   False  4.864340e+09
#                           Equity(42023 [XYL])   False  4.732386e+09
#                           Equity(42118 [GRPN])   True  1.310048e+10
#                           Equity(42173 [DLPH])   True  7.070387e+09
#
#                                                 market_cap_rank   returns  \
# 2011-01-03 00:00:00+00:00 Equity(2 [ARNC])               4632.0  0.013083
#                           Equity(24 [AAPL])              4972.0 -0.003769
#                           Equity(62 [ABT])               4896.0  0.007778
#                           Equity(64 [ABX])               4865.0  0.011217
#                           Equity(67 [ADSK])              4389.0 -0.014952
#                           Equity(76 [TAP])               4428.0 -0.004362
#                           Equity(88 [ACI])               4240.0 -0.005954
#                           Equity(107 [ACV])              4004.0 -0.000270
#                           Equity(114 [ADBE])             4630.0  0.006869
#                           Equity(122 [ADI])              4501.0 -0.007638
#                           Equity(128 [ADM])              4681.0  0.007028
#                           Equity(154 [AEM])              4557.0  0.002354
#                           Equity(157 [AEG])              4478.0  0.008210
#                           Equity(161 [AEP])              4659.0 -0.002495
#                           Equity(166 [AES])              4441.0 -0.002048
#                           Equity(168 [AET])              4532.0  0.002628
#                           Equity(185 [AFL])              4748.0  0.006238
#                           Equity(197 [AGCO])             4149.0 -0.002363
#                           Equity(205 [AGN])              4700.0  0.000000
#                           Equity(216 [HES])              4736.0  0.001308
#                           Equity(239 [AIG])              4351.0  0.001738
#                           Equity(273 [ALU])              4299.0  0.006826
#                           Equity(300 [ALK])              4083.0 -0.013041
#                           Equity(328 [ALTR])             4496.0 -0.009460
#                           Equity(337 [AMAT])             4672.0 -0.006369
#                           Equity(338 [BEAM])             4414.0 -0.007411
#                           Equity(351 [AMD])              4231.0  0.006020
#                           Equity(353 [AME])              4431.0 -0.002034
#                           Equity(357 [TWX])              4801.0  0.003117
#                           Equity(368 [AMGN])             4864.0 -0.011345
# ...                                                         ...       ...
# 2012-01-03 00:00:00+00:00 Equity(39073 [CIE])            4245.0 -0.009591
#                           Equity(39095 [CHTR])           4246.0  0.001408
#                           Equity(39347 [ST])             4125.0 -0.006427
#                           Equity(39495 [SDRL])           4578.0 -0.001806
#                           Equity(39499 [VEON])           4575.0  0.002114
#                           Equity(39546 [LYB])            4626.0 -0.010360
#                           Equity(39612 [SIX])            4116.0 -0.003625
#                           Equity(39778 [QEP])            4186.0  0.002394
#                           Equity(39843 [PACT])           4203.0 -0.004334
#                           Equity(39963 [WPZ])            4058.0  0.015773
#                           Equity(39994 [NXPI])           4019.0 -0.002597
#                           Equity(40338 [SMFG])           4772.0  0.001821
#                           Equity(40430 [GM])             4733.0  0.003414
#                           Equity(40445 [LPLA])           3931.0  0.002626
#                           Equity(40573 [FRC])            4049.0 -0.002603
#                           Equity(40616 [MMI])            4479.0 -0.000258
#                           Equity(40755 [NLSN])           4446.0  0.001350
#                           Equity(40852 [KMI])            4697.0  0.019658
#                           Equity(41047 [HCA])            4415.0  0.035228
#                           Equity(41150 [APO])            4111.0  0.009764
#                           Equity(41242 [ARCO])           4092.0 -0.005329
#                           Equity(41416 [KOS])            4141.0  0.000815
#                           Equity(41451 [LNKD])           4244.0 -0.011471
#                           Equity(41462 [MOS])            4665.0  0.003521
#                           Equity(41484 [YNDX])           4257.0  0.009641
#                           Equity(41636 [MPC])            4485.0  0.001203
#                           Equity(41886 [FNV])            4147.0 -0.008592
#                           Equity(42023 [XYL])            4137.0 -0.011565
#                           Equity(42118 [GRPN])           4522.0 -0.037488
#                           Equity(42173 [DLPH])           4300.0  0.005602
#
#                                                smallest
# 2011-01-03 00:00:00+00:00 Equity(2 [ARNC])        False
#                           Equity(24 [AAPL])       False
#                           Equity(62 [ABT])        False
#                           Equity(64 [ABX])        False
#                           Equity(67 [ADSK])       False
#                           Equity(76 [TAP])        False
#                           Equity(88 [ACI])        False
#                           Equity(107 [ACV])       False
#                           Equity(114 [ADBE])      False
#                           Equity(122 [ADI])       False
#                           Equity(128 [ADM])       False
#                           Equity(154 [AEM])       False
#                           Equity(157 [AEG])       False
#                           Equity(161 [AEP])       False
#                           Equity(166 [AES])       False
#                           Equity(168 [AET])       False
#                           Equity(185 [AFL])       False
#                           Equity(197 [AGCO])      False
#                           Equity(205 [AGN])       False
#                           Equity(216 [HES])       False
#                           Equity(239 [AIG])       False
#                           Equity(273 [ALU])       False
#                           Equity(300 [ALK])       False
#                           Equity(328 [ALTR])      False
#                           Equity(337 [AMAT])      False
#                           Equity(338 [BEAM])      False
#                           Equity(351 [AMD])       False
#                           Equity(353 [AME])       False
#                           Equity(357 [TWX])       False
#                           Equity(368 [AMGN])      False
# ...                                                 ...
# 2012-01-03 00:00:00+00:00 Equity(39073 [CIE])     False
#                           Equity(39095 [CHTR])    False
#                           Equity(39347 [ST])      False
#                           Equity(39495 [SDRL])    False
#                           Equity(39499 [VEON])    False
#                           Equity(39546 [LYB])     False
#                           Equity(39612 [SIX])     False
#                           Equity(39778 [QEP])     False
#                           Equity(39843 [PACT])    False
#                           Equity(39963 [WPZ])     False
#                           Equity(39994 [NXPI])    False
#                           Equity(40338 [SMFG])    False
#                           Equity(40430 [GM])      False
#                           Equity(40445 [LPLA])    False
#                           Equity(40573 [FRC])     False
#                           Equity(40616 [MMI])     False
#                           Equity(40755 [NLSN])    False
#                           Equity(40852 [KMI])     False
#                           Equity(41047 [HCA])     False
#                           Equity(41150 [APO])     False
#                           Equity(41242 [ARCO])    False
#                           Equity(41416 [KOS])     False
#                           Equity(41451 [LNKD])    False
#                           Equity(41462 [MOS])     False
#                           Equity(41484 [YNDX])    False
#                           Equity(41636 [MPC])     False
#                           Equity(41886 [FNV])     False
#                           Equity(42023 [XYL])     False
#                           Equity(42118 [GRPN])    False
#                           Equity(42173 [DLPH])    False
#
# [253000 rows x 9 columns]

# %% [markdown]
# Step 2: Get returns.

# %%
results[results.biggest]['returns']
# Out:
# 2011-01-03 00:00:00+00:00  Equity(2 [ARNC])        0.013083
#                            Equity(24 [AAPL])      -0.003769
#                            Equity(62 [ABT])        0.007778
#                            Equity(64 [ABX])        0.011217
#                            Equity(67 [ADSK])      -0.014952
#                            Equity(76 [TAP])       -0.004362
#                            Equity(88 [ACI])       -0.005954
#                            Equity(107 [ACV])      -0.000270
#                            Equity(114 [ADBE])      0.006869
#                            Equity(122 [ADI])      -0.007638
#                            Equity(128 [ADM])       0.007028
#                            Equity(154 [AEM])       0.002354
#                            Equity(157 [AEG])       0.008210
#                            Equity(161 [AEP])      -0.002495
#                            Equity(166 [AES])      -0.002048
#                            Equity(168 [AET])       0.002628
#                            Equity(185 [AFL])       0.006238
#                            Equity(197 [AGCO])     -0.002363
#                            Equity(205 [AGN])       0.000000
#                            Equity(216 [HES])       0.001308
#                            Equity(239 [AIG])       0.001738
#                            Equity(273 [ALU])       0.006826
#                            Equity(300 [ALK])      -0.013041
#                            Equity(328 [ALTR])     -0.009460
#                            Equity(337 [AMAT])     -0.006369
#                            Equity(338 [BEAM])     -0.007411
#                            Equity(351 [AMD])       0.006020
#                            Equity(353 [AME])      -0.002034
#                            Equity(357 [TWX])       0.003117
#                            Equity(368 [AMGN])     -0.011345
#                                                      ...
# 2012-01-03 00:00:00+00:00  Equity(39073 [CIE])    -0.009591
#                            Equity(39095 [CHTR])    0.001408
#                            Equity(39347 [ST])     -0.006427
#                            Equity(39495 [SDRL])   -0.001806
#                            Equity(39499 [VEON])    0.002114
#                            Equity(39546 [LYB])    -0.010360
#                            Equity(39612 [SIX])    -0.003625
#                            Equity(39778 [QEP])     0.002394
#                            Equity(39843 [PACT])   -0.004334
#                            Equity(39963 [WPZ])     0.015773
#                            Equity(39994 [NXPI])   -0.002597
#                            Equity(40338 [SMFG])    0.001821
#                            Equity(40430 [GM])      0.003414
#                            Equity(40445 [LPLA])    0.002626
#                            Equity(40573 [FRC])    -0.002603
#                            Equity(40616 [MMI])    -0.000258
#                            Equity(40755 [NLSN])    0.001350
#                            Equity(40852 [KMI])     0.019658
#                            Equity(41047 [HCA])     0.035228
#                            Equity(41150 [APO])     0.009764
#                            Equity(41242 [ARCO])   -0.005329
#                            Equity(41416 [KOS])     0.000815
#                            Equity(41451 [LNKD])   -0.011471
#                            Equity(41462 [MOS])     0.003521
#                            Equity(41484 [YNDX])    0.009641
#                            Equity(41636 [MPC])     0.001203
#                            Equity(41886 [FNV])    -0.008592
#                            Equity(42023 [XYL])    -0.011565
#                            Equity(42118 [GRPN])   -0.037488
#                            Equity(42173 [DLPH])    0.005602
# Name: returns, dtype: float64

# %% [markdown]
# Step 3: Group by day and take the mean. This is pretty deep into pandas logic, so if you don't understand this on first pass it is recommended to check out pandas' documentation on all the functions used. Especially `groupby`, which is very useful. Keep in mind that the index in our results is a `MultiIndex` rather than a regular `Index`, that can complicate things.

# %%
results[results.biggest]['returns'].groupby(level=0).mean()
# Out:
# 2011-01-03 00:00:00+00:00   -0.000073
# 2011-01-04 00:00:00+00:00    0.010927
# 2011-01-05 00:00:00+00:00   -0.004852
# 2011-01-06 00:00:00+00:00    0.004119
# 2011-01-07 00:00:00+00:00   -0.003433
# 2011-01-10 00:00:00+00:00   -0.001667
# 2011-01-11 00:00:00+00:00    0.000418
# 2011-01-12 00:00:00+00:00    0.006650
# 2011-01-13 00:00:00+00:00    0.009833
# 2011-01-14 00:00:00+00:00   -0.000769
# 2011-01-18 00:00:00+00:00    0.005220
# 2011-01-19 00:00:00+00:00    0.004294
# 2011-01-20 00:00:00+00:00   -0.012741
# 2011-01-21 00:00:00+00:00   -0.005829
# 2011-01-24 00:00:00+00:00    0.000266
# 2011-01-25 00:00:00+00:00    0.007733
# 2011-01-26 00:00:00+00:00   -0.001141
# 2011-01-27 00:00:00+00:00    0.009474
# 2011-01-28 00:00:00+00:00    0.002992
# 2011-01-31 00:00:00+00:00   -0.017908
# 2011-02-01 00:00:00+00:00    0.009242
# 2011-02-02 00:00:00+00:00    0.016346
# 2011-02-03 00:00:00+00:00   -0.001290
# 2011-02-04 00:00:00+00:00    0.003794
# 2011-02-07 00:00:00+00:00    0.003126
# 2011-02-08 00:00:00+00:00    0.005708
# 2011-02-09 00:00:00+00:00    0.004030
# 2011-02-10 00:00:00+00:00   -0.004297
# 2011-02-11 00:00:00+00:00    0.001948
# 2011-02-14 00:00:00+00:00    0.007066
#                                ...
# 2011-11-18 00:00:00+00:00   -0.018806
# 2011-11-21 00:00:00+00:00   -0.000975
# 2011-11-22 00:00:00+00:00   -0.018174
# 2011-11-23 00:00:00+00:00   -0.004504
# 2011-11-25 00:00:00+00:00   -0.025251
# 2011-11-28 00:00:00+00:00   -0.002599
# 2011-11-29 00:00:00+00:00    0.032981
# 2011-11-30 00:00:00+00:00    0.001957
# 2011-12-01 00:00:00+00:00    0.045410
# 2011-12-02 00:00:00+00:00   -0.001834
# 2011-12-05 00:00:00+00:00   -0.000284
# 2011-12-06 00:00:00+00:00    0.012360
# 2011-12-07 00:00:00+00:00   -0.001624
# 2011-12-08 00:00:00+00:00    0.000452
# 2011-12-09 00:00:00+00:00   -0.025609
# 2011-12-12 00:00:00+00:00    0.018240
# 2011-12-13 00:00:00+00:00   -0.017364
# 2011-12-14 00:00:00+00:00   -0.014827
# 2011-12-15 00:00:00+00:00   -0.013681
# 2011-12-16 00:00:00+00:00    0.004169
# 2011-12-19 00:00:00+00:00    0.005827
# 2011-12-20 00:00:00+00:00   -0.015436
# 2011-12-21 00:00:00+00:00    0.032510
# 2011-12-22 00:00:00+00:00    0.002087
# 2011-12-23 00:00:00+00:00    0.010566
# 2011-12-27 00:00:00+00:00    0.007144
# 2011-12-28 00:00:00+00:00   -0.000272
# 2011-12-29 00:00:00+00:00   -0.015157
# 2011-12-30 00:00:00+00:00    0.011703
# 2012-01-03 00:00:00+00:00   -0.001329
# Name: returns, dtype: float64

# %% [markdown]
# Now run through this computation for each portfolio and get our final results.

# %%
R_biggest = results[results.biggest]['returns'].groupby(level=0).mean()
R_smallest = results[results.smallest]['returns'].groupby(level=0).mean()

R_highpb = results[results.highpb]['returns'].groupby(level=0).mean()
R_lowpb = results[results.lowpb]['returns'].groupby(level=0).mean()

SMB = R_smallest - R_biggest
HML = R_highpb - R_lowpb

# %% [markdown]
# What were the daily returns?

# %%
plt.plot(SMB.index, SMB.values)
plt.ylabel('Daily Percent Return')
plt.legend(['SMB Portfolio Returns']);

# %%
plt.plot(HML.index, HML.values)
plt.ylabel('Daily Percent Return')
plt.legend(['HML Portfolio Returns']);

# %% [markdown]
# And what would it look like to hold these portfolios over time?

# %%
plt.plot(SMB.index, np.cumprod(SMB.values+1))
plt.ylabel('Cumulative Return')
plt.legend(['SMB Portfolio Returns']);

# %% [markdown]
# The last data we need are the daily returns on the broad market.

# %%
M = get_pricing('SPY', start_date='2011-1-1', end_date='2012-1-1', fields='price').pct_change()[1:]

# %%
plt.plot(M.index, M.values)
plt.ylabel('Daily Percent Return')
plt.legend(['Market Portfolio Returns']);

# %% [markdown]
# ###Actually Running the Regression
#
# Now that we have returns series representing our factors, we can compute the factor model for any return stream using a linear regression. Below, we compute the factor sensitivities for returns on a tech portfolio.

# %%
# Get returns data for our portfolio
portfolio = get_pricing(['MSFT', 'AAPL', 'YHOO', 'FB', 'TSLA'], 
                        fields='price', start_date=start_date, end_date=end_date).pct_change()[1:]
R = np.mean(portfolio, axis=1)

# %% [markdown]
# Put all the data into one dataframe for convenience.

# %%
# Define a constant to compute intercept
constant = pd.TimeSeries(np.ones(len(R.index)), index=R.index)

df = pd.DataFrame({'R': R,
              'M': M,
              'SMB': SMB,
              'HML': HML,
              'Constant': constant})
df = df.dropna()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: TimeSeries is deprecated. Please use Series

# %% [markdown]
# Perform the regression. You'll notice that these are the sensitivities over an entire year. It can be valuable to look at the rolling sensitivities as well to determine how stable they are.

# %%
# Perform linear regression to get the coefficients in the model
b1, b2, b3 = regression.linear_model.OLS(df['R'], df[['M', 'SMB', 'HML']]).fit().params

# Print the coefficients from the linear regression
print 'Historical Sensitivities of portfolio returns to factors:\nMarket: %f\nMarket cap: %f\nB/P: %f' %  (b1, b2, b3)
# Out:
# Historical Sensitivities of portfolio returns to factors:
# Market: 0.962979
# Market cap: -0.059429
# B/P: -0.103290

# %% [markdown]
# Let's perform a rolling regression to look at how the estimated sensitivities change over time.

# %%
model = pd.stats.ols.MovingOLS(y = df['R'], x=df[['M', 'SMB', 'HML']], 
                             window_type='rolling', 
                             window=100)
rolling_parameter_estimates = model.beta
rolling_parameter_estimates.plot();
plt.title('Computed Betas');
plt.legend(['Market Beta', 'SMB Beta', 'HML Beta', 'Intercept']);
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: The pandas.stats.ols module is deprecated and will be removed in a future version. We refer to external packages like statsmodels, see some examples here: http://statsmodels.sourceforge.net/stable/regression.html
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ##Approach 2: Factor Value Normalization
#
# ###This is also known as cross-sectional factor analysis.
#
# Another approach is to normalize factor values each bar and see how predictive of that bar's returns they were. We do this by computing a normalized factor value $b_{aj}$ for each asset $a$ in the following way.
#
# $$b_{aj} = \frac{F_{aj} - \mu_{F_j}}{\sigma_{F_j}}$$
#
# $F_{aj}$ is the value of factor $j$ for asset $a$ during this bar, $\mu_{F_j}$ is the mean factor value across all assets, and $\sigma_{F_j}$ is the standard deviation of factor values over all assets. Notice that we are just computing a z-score to make asset specific factor values comparable across different factors.
#
# The exceptions to this formula are indicator variables, which are set to 1 for true and 0 for false. One example is industry membership: the coefficient tells us whether the asset belongs to the industry or not.
#
# After we calculate all of the normalized scores during bar $t$, we can estimate factor $j$'s returns $F_{jt}$, using a cross-sectional regression (i.e. at each time step, we perform a regression using the equations for all of the assets). Specifically, once we have returns for each asset $R_{at}$, and normalized factor coefficients $b_{aj}$, we construct the following model and estimate the $F_j$s and $a_t$
#
# $$R_{at} = a_t + b_{a1}F_1 + b_{a2}F_2 + \dots + b_{aK}F_K$$
#
# You can think of this as slicing through the other direction from the first analysis, as now the factor returns are unknowns to be solved for, whereas originally the coefficients were the unknowns. Another way to think about it is that you're determining how predictive of returns the factor was on that day, and therefore how much return you could have squeezed out of that factor.
#
# Following this procedure, we'll get the cross-sectional returns on 2011-01-03, and compute the coefficients for all assets:

# %% [markdown]
# ###Getting the Data
#
# We already have the results of the previous pipeline call, so we can grab book to price information for 2011-1-3 pretty easily.

# %%
BTP = results['book_to_price']['2011-1-3']
zscore = (BTP - np.mean(BTP)) / np.std(BTP)
zscore.dropna(inplace=True)

plt.hist(zscore)
plt.xlabel('Z-Score')
plt.ylabel('Frequency');

# %% [markdown]
# ###Problem: The Data is Weirdly Distributed
#
# Notice how there are big outliers in the dataset that cause the z-scores to lose a lot of information. Basically the presence of some huge book to price datapoints causes the rest of the data to seem to occupy a relatively small area. We need to get around this issue using some data cleaning technique, here we're use winsorization.
#
# ####Winsorization
#
# Winzorization takes the top $n\%$ of a dataset and sets it all equal to the least extreme value in the top $n\%$. For example, if your dataset ranged from 0-10, plus a few crazy outliers, those outliers would be set to 0 or 10 depending on their direction. Here is an example.

# %%
# Get some random data
X = np.random.normal(0, 1, 100)

# Put in some outliers
X[0] = 1000
X[1] = -1000

# Perform winsorization
print 'Before winsorization', np.min(X), np.max(X)
scipy.stats.mstats.winsorize(X, inplace=True, limits=0.01)
print 'After winsorization', np.min(X), np.max(X)
# Out:
# Before winsorization -1000.0 1000.0
# After winsorization -2.39361794063 2.00542966839

# %% [markdown]
# This looks good, let's see how our book to price data looks when winsorized.

# %%
BTP = results['book_to_price']['2011-1-3']
scipy.stats.mstats.winsorize(BTP, inplace=True, limits=0.01)
BTP_z = (BTP - np.mean(BTP)) / np.std(BTP)
BTP_z.dropna(inplace=True)

plt.hist(BTP_z)
plt.xlabel('Z-Score')
plt.ylabel('Frequency');

# %% [markdown]
# We need the returns for that day as well.

# %%
R_day = results['returns']['2011-1-3']

# %% [markdown]
# Now set up our data and estimate $F_j$ using linear regression.

# %%
constant = pd.TimeSeries(np.ones(len(R_day.index)), index=R_day.index)

df_day = pd.DataFrame({'R': R_day,
              'BTP_z': BTP_z,
              'Constant': constant})
df_day = df_day.dropna()

# Perform linear regression to get the coefficients in the model
F1 = regression.linear_model.OLS(df_day['R'], df_day['BTP_z']).fit().params
print F1
# Out:
# BTP_z    0.001726
# dtype: float64
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: TimeSeries is deprecated. Please use Series
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Finally, let's add another factor so you can see how the code changes.

# %%
MKT = results['market_cap']['2011-1-3']
scipy.stats.mstats.winsorize(MKT, inplace=True, limits=0.01)
MKT_z = (MKT - np.mean(MKT)) / np.std(MKT)

constant = pd.TimeSeries(np.ones(len(R_day.index)), index=R_day.index)

df_day = pd.DataFrame({'R': R_day,
              'BTP_z': BTP_z,
              'MKT_z': MKT_z,
              'Constant': constant})
df_day = df_day.dropna()

# Perform linear regression to get the coefficients in the model
F1, F2 = regression.linear_model.OLS(df_day['R'], df_day[['BTP_z', 'MKT_z']]).fit().params
print F1, F2
# Out:
# 0.00170292160063 0.0002168463866
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: FutureWarning: TimeSeries is deprecated. Please use Series
#   """

# %% [markdown]
# To expand this analysis, you would simply loop through days, running this every day and getting an estimated factor return.

# %% [markdown]
# ##Using Fundamental Factor Modeling
#
# ###Returns Prediction
#
# As discussed in the Arbitrage Price Theory lecture, factor modeling can be used to predict future returns based on current fundamental factors, or to determine when an asset may be mispriced. Modeling future returns is accomplished by offsetting the returns in the regression, so that rather than predicted for current returns, you are predicting for future returns. Once you have a predictive model, the most canonical way to create a strategy is to attempt a long-short equity approach.
#
# There is a full lecture describing long-short equity, but the general idea is that you rank equities based on their predicted future returns. You then long the top p% and short the bottom p% remaining neutral on dollar volume. If the assets at the top of the ranking on average tend to make $5\%$ more per year than the market, and assets at the bottom tend to make $5\%$ less, then you will make $(M + 0.05) - (M - 0.05) = 0.10$ or $10\%$ percent per year, where $M$ is the market return that gets canceled out.
#
# ###Hedging out Exposure
#
# Once we've determined that we are exposed to a factor, we may want to avoid depending on the performance of that factor by taking out a hedge. This is discussed in the Beta Hedging lecture and also in the Risk Factor Exposure notebook.

# %% [markdown]
# *This presentation is for informational purposes only and does not constitute an offer to sell, a solicitation to buy, or a recommendation for any security; nor does it constitute an offer to provide investment advisory or other services by Quantopian, Inc. ("Quantopian"). Nothing contained herein constitutes investment advice or offers any opinion with respect to the suitability of any security, and any views expressed herein should not be taken as advice to buy, sell, or hold any security or as an endorsement of any security or company.  In preparing the information contained herein, Quantopian, Inc. has not taken into account the investment needs, objectives, and financial circumstances of any particular investor. Any views expressed and data illustrated herein were prepared based upon information, believed to be reliable, available to Quantopian, Inc. at the time of publication. Quantopian makes no guarantees as to their accuracy or completeness. All information is subject to change and may quickly become unreliable for various reasons, including changes in market conditions or economic circumstances.*
