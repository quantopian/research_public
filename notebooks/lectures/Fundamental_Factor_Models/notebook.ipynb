# %% [markdown]
# # Fundamental Factor Models
#
# By Beha Abasi, Maxwell Margenot, and Delaney Granizo-Mackenzie
#
# Part of the Quantopian Lecture Series:
#
# * [www.quantopian.com/lectures](https://www.quantopian.com/lectures)
# * [github.com/quantopian/research_public](https://github.com/quantopian/research_public)
#
# Notebook released under the Creative Commons Attribution 4.0 License.

# %% [markdown]
# ##What are Fundamental Factor Models?
#
# Fundamental data refers to the metrics and ratios measuring the financial performance of companies and is derived from the public filings made by these companies. We will get our fundamental data from Morningstar.
#
# This fundamental data can be used in many ways, one of which is to build a linear factor model. Given a set of $k$ fundamental factors, we can represent the returns of an asset as follows:
#
# $$R_t = a_t + \beta_{t, F_1}F_1 + \beta_{t, F_2}F_2 + ... + \beta_{t, F_k}F_k + \epsilon_t$$
#
# where each $F_j$ represents a fundamental factor return stream. These return streams are from portfolios whose value is derived from it's respective factor.
#
# Fundamental factor models try to determine characteristics that affect an asset's risk and return. The most difficult part of this is determining which factors to use. Much research has been done on determining significant factors, and what makes things even more difficult is that the discovery of a significant factor often leads to its advantage being arbitraged away! This is one of the reasons why fundamental factor models, and linear factor models in general, are so prevalent in modern finance. Once you've found significant factors, you'll need to calculate the exposure an asset's return stream has to each factor. This is similar to the calculation of risk premia discussed in the CAPM lecture.
#
# In using fundamental data, we run into the problem of having factors that may not be easily comparable due to their varying units and magnitudes. To resolve this we will manipulate the data so that it makes sense to compare different factors. In general, there are two ways of using fundamental factor models - by portfolio construction and by factor value normalization.

# %% [markdown]
# ## Approach One: Portfolio Construction

# %% [markdown]
# The first approach consists of using the fundamental data as a ranking scheme and creating a long-short equity portfolio based on each factor. We then use the return streams associated with each portfolio as our model factors.
#
# One of the most well known examples of this approach is the Fama-French model. The Fama-French model, and later the Carhart four factor model which we will implement, adds market cap, book-to-price ratios, and momentum to the original CAPM market risk model.
#
# The idea to use those factors comes from the fact that certain groups of stocks were seen as historically outperforming the market, namely those with small market caps, high book-to-price ratios, and those that had previously done well (i.e., they had momentum). Empirically, Fama & French found that the returns of these particular types of stocks tended to be better than what was predicted by the security market line of the CAPM.
#
# In order to capture these phenomena, we will use those factors to create a ranking scheme that will be used in the creation of long short equity portfolios. The factors will be $SMB$, measuring the excess return of small market cap companies minus big; $HML$, measuring the excess return of companies with high book-to-price ratios versus low; $MOM$, measuring the excess returns of last month's winners versus last month's losers; and $EXMRKT$ which is a measure of the market risk.
#
# In general, this approach can be used as an asset pricing model or to hedge our portfolios. The latter uses the Fama-Macbeth regressions to calculate risk premia, as demonstrated in the CAPM lecture. Hedging can be achieved through a linear regression of portfolio returns on the returns from the long-short factor portfolios. Below are examples of both.

# %% [markdown]
# ### Portfolio Construction as an Asset Pricing Model

# %% [markdown]
# First, we'll import the relevant libraries.

# %%
import pandas as pd
from quantopian.pipeline import Pipeline
from quantopian.pipeline.data import morningstar
from quantopian.pipeline.factors import CustomFactor, Returns, Latest
from quantopian.pipeline.filters.morningstar import Q1500US
from quantopian.research import run_pipeline
from quantopian.pipeline.classifiers.morningstar import Sector
import matplotlib.pyplot as plt

# %% [markdown]
# Use pipeline to get all of our factor data that we will use in the rest of the lecture.

# %%
class LaggedReturns(CustomFactor):
    # will give us the returns from last month
    inputs = [Returns(window_length=273)]
    window_length = 273
    
    def compute(self, today, assets, out, lag_returns):
        m = today.month # need to fix this
        
        out[:] = lag_returns[(21 * m) - 1] / lag_returns[21 * (m - 1)]

class BookToPrice(CustomFactor):
    # pb = price to book, but we return the reciprocal
    inputs = [morningstar.valuation_ratios.pb_ratio]
    window_length = 1
    
    def compute(self, today, assets, out, pb):
        out[:] = 1 / pb

def make_pipeline():
    # define our fundamental factor pipeline
    pipe = Pipeline()
    
    # market cap and book-to-price data gets fed in here
    market_cap = Latest([morningstar.valuation.market_cap])
    pipe.add(market_cap, "market_cap")
    
    book_to_price = BookToPrice()
    pipe.add(book_to_price, "book_to_price")
    
    # we also get daily returns
    returns = Returns(window_length=2)
    pipe.add(returns, "Returns")
    
    # and lagged returns (1 month lag)
    lagged_returns = LaggedReturns()
    pipe.add(lagged_returns, 'lagged_returns')
    
    # we compute a daily rank of both factors, this is used in the next step,
    # which is computing portfolio membership
    market_cap_rank = market_cap.rank(mask=Q1500US())
    pipe.add(market_cap_rank, 'market_cap_rank')
    
    book_to_price_rank = book_to_price.rank(mask=Q1500US())
    pipe.add(book_to_price_rank, 'book_to_price_rank')
    
    lagged_returns_rank = lagged_returns.rank(mask=Q1500US())
    pipe.add(lagged_returns_rank, 'lagged_returns_rank')

    # build Filters representing the top and bottom 1000 stocks by our combined ranking system
    biggest = market_cap_rank.top(1000)
    smallest = market_cap_rank.bottom(1000)
    
    highpb = book_to_price_rank.top(1000)
    lowpb = book_to_price_rank.bottom(1000)
    
    top = lagged_returns_rank.top(1000)
    bottom = lagged_returns_rank.bottom(1000)
        
    # don't return anything not in this set, as we don't need it
    pipe.set_screen(Q1500US() & (biggest | smallest | highpb | lowpb | top | bottom))
    
    # add the boolean flags we computed to the output data
    pipe.add(biggest, 'biggest')
    pipe.add(smallest, 'smallest')
    
    pipe.add(highpb, 'highpb')
    pipe.add(lowpb, 'lowpb')
    
    pipe.add(top, 'top')
    pipe.add(bottom, 'bottom')
    
    return pipe

# Initializing the pipe
pipe = make_pipeline()

# Dependency Graph
pipe.show_graph('png')

# Now let's start the pipeline
lagged_start_date = '2015-12-01'
start_date, end_date = '2016-01-01', '2016-12-31' # the actual dates over which we'll conduct our test

results = run_pipeline(pipe, lagged_start_date, end_date)

results
# Out:
#                                                    Returns biggest  \
# 2015-12-01 00:00:00+00:00 Equity(2 [ARNC])        0.005371    True
#                           Equity(24 [AAPL])       0.004668    True
#                           Equity(53 [ABMD])      -0.022528    True
#                           Equity(62 [ABT])       -0.011224    True
#                           Equity(67 [ADSK])       0.006661    True
#                           Equity(76 [TAP])       -0.014777    True
#                           Equity(114 [ADBE])     -0.007487    True
#                           Equity(122 [ADI])       0.020017    True
#                           Equity(128 [ADM])       0.001096    True
#                           Equity(161 [AEP])       0.001072    True
#                           Equity(166 [AES])       0.002002    True
#                           Equity(168 [AET])      -0.012007    True
#                           Equity(185 [AFL])      -0.000934    True
#                           Equity(197 [AGCO])      0.004596    True
#                           Equity(216 [HES])      -0.001691    True
#                           Equity(239 [AIG])      -0.001413    True
#                           Equity(266 [AJG])      -0.004776    True
#                           Equity(270 [AKRX])     -0.004782    True
#                           Equity(300 [ALK])      -0.000752    True
#                           Equity(301 [ALKS])     -0.030159    True
#                           Equity(328 [ALTR])      0.000379    True
#                           Equity(337 [AMAT])      0.009130    True
#                           Equity(351 [AMD])       0.012876   False
#                           Equity(353 [AME])      -0.006684    True
#                           Equity(357 [TWX])       0.003008    True
#                           Equity(368 [AMGN])     -0.013942    True
#                           Equity(410 [AN])       -0.006218    True
#                           Equity(438 [AON])       0.000845    True
#                           Equity(448 [APA])      -0.005057    True
#                           Equity(455 [APC])      -0.013660    True
# ...                                                    ...     ...
# 2017-01-03 00:00:00+00:00 Equity(48547 [ONCE])   -0.013639   False
#                           Equity(48629 [INOV])    0.009852   False
#                           Equity(48746 [SUM])    -0.014085   False
#                           Equity(48823 [SEDG])    0.012195   False
#                           Equity(48863 [GDDY])    0.001146    True
#                           Equity(48892 [IGT])     0.008294    True
#                           Equity(48934 [ETSY])    0.003404   False
#                           Equity(48962 [UNIT])   -0.009743    True
#                           Equity(49051 [APLE])    0.005536    True
#                           Equity(49060 [SHOP])   -0.005336    True
#                           Equity(49138 [UNVR])   -0.007172    True
#                           Equity(49176 [TRU])     0.008127    True
#                           Equity(49178 [GKOS])   -0.008671   False
#                           Equity(49238 [SRG])     0.005178   False
#                           Equity(49242 [PYPL])   -0.012509    True
#                           Equity(49288 [LITE])   -0.016539   False
#                           Equity(49318 [BETR])   -0.005079   False
#                           Equity(49322 [PLNT])    0.002994   False
#                           Equity(49325 [CCP])     0.016673   False
#                           Equity(49496 [FDC])    -0.006998    True
#                           Equity(49506 [HPE])    -0.008565    True
#                           Equity(49515 [RACE])    0.006056    True
#                           Equity(49630 [CSRA])   -0.002974    True
#                           Equity(49700 [FCE_A])   0.024582    True
#                           Equity(49751 [AVXS])    0.004631   False
#                           Equity(49760 [WBT])     0.020053   False
#                           Equity(49881 [LSXM_A])  0.000870    True
#                           Equity(50138 [PI])      0.003976   False
#                           Equity(50357 [ARCH])   -0.001280   False
#                           Equity(50499 [EVHC])   -0.015552    True
#
#                                                   book_to_price  \
# 2015-12-01 00:00:00+00:00 Equity(2 [ARNC])             1.016880
#                           Equity(24 [AAPL])            0.181376
#                           Equity(53 [ABMD])            0.095098
#                           Equity(62 [ABT])             0.311653
#                           Equity(67 [ADSK])            0.133645
#                           Equity(76 [TAP])             0.424809
#                           Equity(114 [ADBE])           0.149457
#                           Equity(122 [ADI])            0.269811
#                           Equity(128 [ADM])            0.820816
#                           Equity(161 [AEP])            0.648466
#                           Equity(166 [AES])            0.536567
#                           Equity(168 [AET])            0.437790
#                           Equity(185 [AFL])            0.621118
#                           Equity(197 [AGCO])           0.687380
#                           Equity(216 [HES])            1.224740
#                           Equity(239 [AIG])            1.267267
#                           Equity(266 [AJG])            0.470323
#                           Equity(270 [AKRX])           0.100707
#                           Equity(300 [ALK])            0.235532
#                           Equity(301 [ALKS])           0.122988
#                           Equity(328 [ALTR])           0.209608
#                           Equity(337 [AMAT])           0.360114
#                           Equity(351 [AMD])            0.011321
#                           Equity(353 [AME])            0.246840
#                           Equity(357 [TWX])            0.420751
#                           Equity(368 [AMGN])           0.226137
#                           Equity(410 [AN])             0.316877
#                           Equity(438 [AON])            0.227247
#                           Equity(448 [APA])            0.515358
#                           Equity(455 [APC])            0.453248
# ...                                                         ...
# 2017-01-03 00:00:00+00:00 Equity(48547 [ONCE])         0.230979
#                           Equity(48629 [INOV])         0.488234
#                           Equity(48746 [SUM])          0.263248
#                           Equity(48823 [SEDG])         0.546597
#                           Equity(48863 [GDDY])         0.087008
#                           Equity(48892 [IGT])          0.672585
#                           Equity(48934 [ETSY])         0.253447
#                           Equity(48962 [UNIT])              NaN
#                           Equity(49051 [APLE])         0.795988
#                           Equity(49060 [SHOP])         0.107358
#                           Equity(49138 [UNVR])         0.217827
#                           Equity(49176 [TRU])          0.232229
#                           Equity(49178 [GKOS])         0.094937
#                           Equity(49238 [SRG])          0.349138
#                           Equity(49242 [PYPL])         0.294334
#                           Equity(49288 [LITE])         0.194609
#                           Equity(49318 [BETR])         0.093512
#                           Equity(49322 [PLNT])         0.004757
#                           Equity(49325 [CCP])          0.559065
#                           Equity(49496 [FDC])          0.079792
#                           Equity(49506 [HPE])          0.809323
#                           Equity(49515 [RACE])         0.016818
#                           Equity(49630 [CSRA])         0.033718
#                           Equity(49700 [FCE_A])        0.563571
#                           Equity(49751 [AVXS])         0.203227
#                           Equity(49760 [WBT])          0.559754
#                           Equity(49881 [LSXM_A])       0.867754
#                           Equity(50138 [PI])           0.117345
#                           Equity(50357 [ARCH])        42.016807
#                           Equity(50499 [EVHC])         0.487520
#
#                                                   book_to_price_rank bottom  \
# 2015-12-01 00:00:00+00:00 Equity(2 [ARNC])                    1369.0   True
#                           Equity(24 [AAPL])                    369.0  False
#                           Equity(53 [ABMD])                    171.0   True
#                           Equity(62 [ABT])                     693.0   True
#                           Equity(67 [ADSK])                    249.0   True
#                           Equity(76 [TAP])                     923.0   True
#                           Equity(114 [ADBE])                   293.0  False
#                           Equity(122 [ADI])                    605.0  False
#                           Equity(128 [ADM])                   1289.0   True
#                           Equity(161 [AEP])                   1178.0   True
#                           Equity(166 [AES])                   1073.0   True
#                           Equity(168 [AET])                    936.0   True
#                           Equity(185 [AFL])                   1150.0   True
#                           Equity(197 [AGCO])                  1219.0   True
#                           Equity(216 [HES])                   1414.0   True
#                           Equity(239 [AIG])                   1423.0  False
#                           Equity(266 [AJG])                    989.0   True
#                           Equity(270 [AKRX])                   181.0   True
#                           Equity(300 [ALK])                    512.0   True
#                           Equity(301 [ALKS])                   225.0  False
#                           Equity(328 [ALTR])                   447.0   True
#                           Equity(337 [AMAT])                   801.0   True
#                           Equity(351 [AMD])                     33.0   True
#                           Equity(353 [AME])                    546.0   True
#                           Equity(357 [TWX])                    915.0   True
#                           Equity(368 [AMGN])                   492.0  False
#                           Equity(410 [AN])                     702.0  False
#                           Equity(438 [AON])                    495.0  False
#                           Equity(448 [APA])                   1056.0   True
#                           Equity(455 [APC])                    960.0   True
# ...                                                              ...    ...
# 2017-01-03 00:00:00+00:00 Equity(48547 [ONCE])                 487.0  False
#                           Equity(48629 [INOV])                1017.0  False
#                           Equity(48746 [SUM])                  577.0  False
#                           Equity(48823 [SEDG])                1099.0  False
#                           Equity(48863 [GDDY])                 147.0  False
#                           Equity(48892 [IGT])                 1248.0  False
#                           Equity(48934 [ETSY])                 553.0  False
#                           Equity(48962 [UNIT])                   NaN  False
#                           Equity(49051 [APLE])                1336.0  False
#                           Equity(49060 [SHOP])                 178.0  False
#                           Equity(49138 [UNVR])                 452.0  False
#                           Equity(49176 [TRU])                  494.0  False
#                           Equity(49178 [GKOS])                 159.0  False
#                           Equity(49238 [SRG])                  770.0  False
#                           Equity(49242 [PYPL])                 661.0  False
#                           Equity(49288 [LITE])                 391.0  False
#                           Equity(49318 [BETR])                 157.0  False
#                           Equity(49322 [PLNT])                  15.0  False
#                           Equity(49325 [CCP])                 1118.0  False
#                           Equity(49496 [FDC])                  132.0  False
#                           Equity(49506 [HPE])                 1348.0  False
#                           Equity(49515 [RACE])                  43.0  False
#                           Equity(49630 [CSRA])                  72.0  False
#                           Equity(49700 [FCE_A])               1126.0  False
#                           Equity(49751 [AVXS])                 418.0  False
#                           Equity(49760 [WBT])                 1119.0  False
#                           Equity(49881 [LSXM_A])              1374.0  False
#                           Equity(50138 [PI])                   205.0  False
#                           Equity(50357 [ARCH])                1493.0  False
#                           Equity(50499 [EVHC])                1016.0  False
#
#                                                  highpb  lagged_returns  \
# 2015-12-01 00:00:00+00:00 Equity(2 [ARNC])         True        0.950510
#                           Equity(24 [AAPL])       False        1.866871
#                           Equity(53 [ABMD])       False        0.754950
#                           Equity(62 [ABT])         True       -4.822327
#                           Equity(67 [ADSK])       False        0.051311
#                           Equity(76 [TAP])         True        1.406199
#                           Equity(114 [ADBE])      False        1.950089
#                           Equity(122 [ADI])        True        2.242294
#                           Equity(128 [ADM])        True        0.508646
#                           Equity(161 [AEP])        True        1.237128
#                           Equity(166 [AES])        True        0.645737
#                           Equity(168 [AET])        True        1.318241
#                           Equity(185 [AFL])        True       -5.487522
#                           Equity(197 [AGCO])       True       -1.028241
#                           Equity(216 [HES])        True        0.774801
#                           Equity(239 [AIG])        True        5.590833
#                           Equity(266 [AJG])        True       -0.192714
#                           Equity(270 [AKRX])      False        0.935160
#                           Equity(300 [ALK])        True        1.122733
#                           Equity(301 [ALKS])      False        2.014571
#                           Equity(328 [ALTR])      False        1.208342
#                           Equity(337 [AMAT])       True        0.533889
#                           Equity(351 [AMD])       False        0.625027
#                           Equity(353 [AME])        True      -12.643699
#                           Equity(357 [TWX])        True       -0.476346
#                           Equity(368 [AMGN])       True        5.784797
#                           Equity(410 [AN])         True        3.587436
#                           Equity(438 [AON])        True        5.309810
#                           Equity(448 [APA])        True        0.798482
#                           Equity(455 [APC])        True        0.696708
# ...                                                 ...             ...
# 2017-01-03 00:00:00+00:00 Equity(48547 [ONCE])    False             NaN
#                           Equity(48629 [INOV])     True             NaN
#                           Equity(48746 [SUM])      True             NaN
#                           Equity(48823 [SEDG])     True             NaN
#                           Equity(48863 [GDDY])    False             NaN
#                           Equity(48892 [IGT])      True             NaN
#                           Equity(48934 [ETSY])     True             NaN
#                           Equity(48962 [UNIT])    False             NaN
#                           Equity(49051 [APLE])     True             NaN
#                           Equity(49060 [SHOP])    False             NaN
#                           Equity(49138 [UNVR])    False             NaN
#                           Equity(49176 [TRU])      True             NaN
#                           Equity(49178 [GKOS])    False             NaN
#                           Equity(49238 [SRG])      True             NaN
#                           Equity(49242 [PYPL])     True             NaN
#                           Equity(49288 [LITE])    False             NaN
#                           Equity(49318 [BETR])    False             NaN
#                           Equity(49322 [PLNT])    False             NaN
#                           Equity(49325 [CCP])      True             NaN
#                           Equity(49496 [FDC])     False             NaN
#                           Equity(49506 [HPE])      True             NaN
#                           Equity(49515 [RACE])    False             NaN
#                           Equity(49630 [CSRA])    False             NaN
#                           Equity(49700 [FCE_A])    True             NaN
#                           Equity(49751 [AVXS])    False             NaN
#                           Equity(49760 [WBT])      True             NaN
#                           Equity(49881 [LSXM_A])   True             NaN
#                           Equity(50138 [PI])      False             NaN
#                           Equity(50357 [ARCH])     True             NaN
#                           Equity(50499 [EVHC])     True             NaN
#
#                                                   lagged_returns_rank  lowpb  \
# 2015-12-01 00:00:00+00:00 Equity(2 [ARNC])                      770.0  False
#                           Equity(24 [AAPL])                    1157.0   True
#                           Equity(53 [ABMD])                     598.0   True
#                           Equity(62 [ABT])                       50.0   True
#                           Equity(67 [ADSK])                     269.0   True
#                           Equity(76 [TAP])                      997.0   True
#                           Equity(114 [ADBE])                   1179.0   True
#                           Equity(122 [ADI])                    1238.0   True
#                           Equity(128 [ADM])                     422.0  False
#                           Equity(161 [AEP])                     933.0  False
#                           Equity(166 [AES])                     521.0  False
#                           Equity(168 [AET])                     967.0   True
#                           Equity(185 [AFL])                      42.0  False
#                           Equity(197 [AGCO])                    134.0  False
#                           Equity(216 [HES])                     615.0  False
#                           Equity(239 [AIG])                    1393.0  False
#                           Equity(266 [AJG])                     212.0   True
#                           Equity(270 [AKRX])                    760.0   True
#                           Equity(300 [ALK])                     871.0   True
#                           Equity(301 [ALKS])                   1194.0   True
#                           Equity(328 [ALTR])                    922.0   True
#                           Equity(337 [AMAT])                    438.0   True
#                           Equity(351 [AMD])                     503.0   True
#                           Equity(353 [AME])                      18.0   True
#                           Equity(357 [TWX])                     180.0   True
#                           Equity(368 [AMGN])                   1398.0   True
#                           Equity(410 [AN])                     1349.0   True
#                           Equity(438 [AON])                    1389.0   True
#                           Equity(448 [APA])                     641.0  False
#                           Equity(455 [APC])                     550.0   True
# ...                                                               ...    ...
# 2017-01-03 00:00:00+00:00 Equity(48547 [ONCE])                    NaN   True
#                           Equity(48629 [INOV])                    NaN  False
#                           Equity(48746 [SUM])                     NaN   True
#                           Equity(48823 [SEDG])                    NaN  False
#                           Equity(48863 [GDDY])                    NaN   True
#                           Equity(48892 [IGT])                     NaN  False
#                           Equity(48934 [ETSY])                    NaN   True
#                           Equity(48962 [UNIT])                    NaN  False
#                           Equity(49051 [APLE])                    NaN  False
#                           Equity(49060 [SHOP])                    NaN   True
#                           Equity(49138 [UNVR])                    NaN   True
#                           Equity(49176 [TRU])                     NaN   True
#                           Equity(49178 [GKOS])                    NaN   True
#                           Equity(49238 [SRG])                     NaN   True
#                           Equity(49242 [PYPL])                    NaN   True
#                           Equity(49288 [LITE])                    NaN   True
#                           Equity(49318 [BETR])                    NaN   True
#                           Equity(49322 [PLNT])                    NaN   True
#                           Equity(49325 [CCP])                     NaN  False
#                           Equity(49496 [FDC])                     NaN   True
#                           Equity(49506 [HPE])                     NaN  False
#                           Equity(49515 [RACE])                    NaN   True
#                           Equity(49630 [CSRA])                    NaN   True
#                           Equity(49700 [FCE_A])                   NaN  False
#                           Equity(49751 [AVXS])                    NaN   True
#                           Equity(49760 [WBT])                     NaN  False
#                           Equity(49881 [LSXM_A])                  NaN  False
#                           Equity(50138 [PI])                      NaN   True
#                           Equity(50357 [ARCH])                    NaN  False
#                           Equity(50499 [EVHC])                    NaN  False
#
#                                                     market_cap  \
# 2015-12-01 00:00:00+00:00 Equity(2 [ARNC])        1.232830e+10
#                           Equity(24 [AAPL])       6.580560e+11
#                           Equity(53 [ABMD])       3.481630e+09
#                           Equity(62 [ABT])        6.773900e+10
#                           Equity(67 [ADSK])       1.423240e+10
#                           Equity(76 [TAP])        1.706760e+10
#                           Equity(114 [ADBE])      4.577480e+10
#                           Equity(122 [ADI])       1.880170e+10
#                           Equity(128 [ADM])       2.176310e+10
#                           Equity(161 [AEP])       2.729440e+10
#                           Equity(166 [AES])       6.647880e+09
#                           Equity(168 [AET])       3.624740e+10
#                           Equity(185 [AFL])       2.778070e+10
#                           Equity(197 [AGCO])      4.258880e+09
#                           Equity(216 [HES])       1.741760e+10
#                           Equity(239 [AIG])       7.811730e+10
#                           Equity(266 [AJG])       7.765750e+09
#                           Equity(270 [AKRX])      3.840370e+09
#                           Equity(300 [ALK])       1.004110e+10
#                           Equity(301 [ALKS])      1.111330e+10
#                           Equity(328 [ALTR])      1.599390e+10
#                           Equity(337 [AMAT])      2.215140e+10
#                           Equity(351 [AMD])       1.880650e+09
#                           Equity(353 [AME])       1.343090e+10
#                           Equity(357 [TWX])       5.620340e+10
#                           Equity(368 [AMGN])      1.236720e+11
#                           Equity(410 [AN])        7.147470e+09
#                           Equity(438 [AON])       2.588790e+10
#                           Equity(448 [APA])       1.903300e+10
#                           Equity(455 [APC])       3.106280e+10
# ...                                                        ...
# 2017-01-03 00:00:00+00:00 Equity(48547 [ONCE])    1.556500e+09
#                           Equity(48629 [INOV])    1.492320e+09
#                           Equity(48746 [SUM])     2.942650e+09
#                           Equity(48823 [SEDG])    5.030240e+08
#                           Equity(48863 [GDDY])    5.793740e+09
#                           Equity(48892 [IGT])     5.086170e+09
#                           Equity(48934 [ETSY])    1.359090e+09
#                           Equity(48962 [UNIT])    3.997560e+09
#                           Equity(49051 [APLE])    4.442690e+09
#                           Equity(49060 [SHOP])    3.833150e+09
#                           Equity(49138 [UNVR])    3.960960e+09
#                           Equity(49176 [TRU])     5.625950e+09
#                           Equity(49178 [GKOS])    1.160800e+09
#                           Equity(49238 [SRG])     2.369290e+09
#                           Equity(49242 [PYPL])    4.821760e+10
#                           Equity(49288 [LITE])    2.363200e+09
#                           Equity(49318 [BETR])    6.810770e+08
#                           Equity(49322 [PLNT])    1.989490e+09
#                           Equity(49325 [CCP])     2.064590e+09
#                           Equity(49496 [FDC])     1.300890e+10
#                           Equity(49506 [HPE])     3.885680e+10
#                           Equity(49515 [RACE])    1.418270e+10
#                           Equity(49630 [CSRA])    5.219830e+09
#                           Equity(49700 [FCE_A])   5.283200e+09
#                           Equity(49751 [AVXS])    1.314900e+09
#                           Equity(49760 [WBT])     2.624690e+09
#                           Equity(49881 [LSXM_A])  1.155450e+10
#                           Equity(50138 [PI])      7.140120e+08
#                           Equity(50357 [ARCH])    1.953200e+09
#                           Equity(50499 [EVHC])    4.229650e+09
#
#                                                   market_cap_rank smallest  \
# 2015-12-01 00:00:00+00:00 Equity(2 [ARNC])                 1142.0    False
#                           Equity(24 [AAPL])                1500.0    False
#                           Equity(53 [ABMD])                 609.0     True
#                           Equity(62 [ABT])                 1436.0    False
#                           Equity(67 [ADSK])                1184.0    False
#                           Equity(76 [TAP])                 1227.0    False
#                           Equity(114 [ADBE])               1401.0    False
#                           Equity(122 [ADI])                1253.0    False
#                           Equity(128 [ADM])                1281.0    False
#                           Equity(161 [AEP])                1327.0    False
#                           Equity(166 [AES])                 923.0     True
#                           Equity(168 [AET])                1378.0    False
#                           Equity(185 [AFL])                1329.0    False
#                           Equity(197 [AGCO])                720.0     True
#                           Equity(216 [HES])                1230.0    False
#                           Equity(239 [AIG])                1446.0    False
#                           Equity(266 [AJG])                 985.0     True
#                           Equity(270 [AKRX])                663.0     True
#                           Equity(300 [ALK])                1079.0    False
#                           Equity(301 [ALKS])               1115.0    False
#                           Equity(328 [ALTR])               1209.0    False
#                           Equity(337 [AMAT])               1287.0    False
#                           Equity(351 [AMD])                 267.0     True
#                           Equity(353 [AME])                1169.0    False
#                           Equity(357 [TWX])                1417.0    False
#                           Equity(368 [AMGN])               1467.0    False
#                           Equity(410 [AN])                  957.0     True
#                           Equity(438 [AON])                1317.0    False
#                           Equity(448 [APA])                1255.0    False
#                           Equity(455 [APC])                1352.0    False
# ...                                                           ...      ...
# 2017-01-03 00:00:00+00:00 Equity(48547 [ONCE])              176.0     True
#                           Equity(48629 [INOV])              159.0     True
#                           Equity(48746 [SUM])               481.0     True
#                           Equity(48823 [SEDG])                2.0     True
#                           Equity(48863 [GDDY])              846.0     True
#                           Equity(48892 [IGT])               787.0     True
#                           Equity(48934 [ETSY])              134.0     True
#                           Equity(48962 [UNIT])              664.0     True
#                           Equity(49051 [APLE])              723.0     True
#                           Equity(49060 [SHOP])              635.0     True
#                           Equity(49138 [UNVR])              658.0     True
#                           Equity(49176 [TRU])               833.0     True
#                           Equity(49178 [GKOS])               89.0     True
#                           Equity(49238 [SRG])               346.0     True
#                           Equity(49242 [PYPL])             1399.0    False
#                           Equity(49288 [LITE])              342.0     True
#                           Equity(49318 [BETR])               16.0     True
#                           Equity(49322 [PLNT])              269.0     True
#                           Equity(49325 [CCP])               282.0     True
#                           Equity(49496 [FDC])              1144.0    False
#                           Equity(49506 [HPE])              1375.0    False
#                           Equity(49515 [RACE])             1171.0    False
#                           Equity(49630 [CSRA])              798.0     True
#                           Equity(49700 [FCE_A])             804.0     True
#                           Equity(49751 [AVXS])              124.0     True
#                           Equity(49760 [WBT])               408.0     True
#                           Equity(49881 [LSXM_A])           1113.0    False
#                           Equity(50138 [PI])                 24.0     True
#                           Equity(50357 [ARCH])              257.0     True
#                           Equity(50499 [EVHC])              690.0     True
#
#                                                     top
# 2015-12-01 00:00:00+00:00 Equity(2 [ARNC])         True
#                           Equity(24 [AAPL])        True
#                           Equity(53 [ABMD])        True
#                           Equity(62 [ABT])        False
#                           Equity(67 [ADSK])       False
#                           Equity(76 [TAP])         True
#                           Equity(114 [ADBE])       True
#                           Equity(122 [ADI])        True
#                           Equity(128 [ADM])       False
#                           Equity(161 [AEP])        True
#                           Equity(166 [AES])        True
#                           Equity(168 [AET])        True
#                           Equity(185 [AFL])       False
#                           Equity(197 [AGCO])      False
#                           Equity(216 [HES])        True
#                           Equity(239 [AIG])        True
#                           Equity(266 [AJG])       False
#                           Equity(270 [AKRX])       True
#                           Equity(300 [ALK])        True
#                           Equity(301 [ALKS])       True
#                           Equity(328 [ALTR])       True
#                           Equity(337 [AMAT])      False
#                           Equity(351 [AMD])        True
#                           Equity(353 [AME])       False
#                           Equity(357 [TWX])       False
#                           Equity(368 [AMGN])       True
#                           Equity(410 [AN])         True
#                           Equity(438 [AON])        True
#                           Equity(448 [APA])        True
#                           Equity(455 [APC])        True
# ...                                                 ...
# 2017-01-03 00:00:00+00:00 Equity(48547 [ONCE])    False
#                           Equity(48629 [INOV])    False
#                           Equity(48746 [SUM])     False
#                           Equity(48823 [SEDG])    False
#                           Equity(48863 [GDDY])    False
#                           Equity(48892 [IGT])     False
#                           Equity(48934 [ETSY])    False
#                           Equity(48962 [UNIT])    False
#                           Equity(49051 [APLE])    False
#                           Equity(49060 [SHOP])    False
#                           Equity(49138 [UNVR])    False
#                           Equity(49176 [TRU])     False
#                           Equity(49178 [GKOS])    False
#                           Equity(49238 [SRG])     False
#                           Equity(49242 [PYPL])    False
#                           Equity(49288 [LITE])    False
#                           Equity(49318 [BETR])    False
#                           Equity(49322 [PLNT])    False
#                           Equity(49325 [CCP])     False
#                           Equity(49496 [FDC])     False
#                           Equity(49506 [HPE])     False
#                           Equity(49515 [RACE])    False
#                           Equity(49630 [CSRA])    False
#                           Equity(49700 [FCE_A])   False
#                           Equity(49751 [AVXS])    False
#                           Equity(49760 [WBT])     False
#                           Equity(49881 [LSXM_A])  False
#                           Equity(50138 [PI])      False
#                           Equity(50357 [ARCH])    False
#                           Equity(50499 [EVHC])    False
#
# [410352 rows x 13 columns]

# %% [markdown]
# We'll remove the data from the lagged_start_date to start_date

# %%
results = results.loc[pd.datetime(2016,1,1):pd.datetime(2016,12,31)]

# %% [markdown]
# Now we can go through the data and build the factor portfolios we want

# %%
# group_by(level=0).mean() gives you the average return of each day for a particular group of stocks

R_biggest = results[results.biggest]['Returns'].groupby(level=0).mean()
R_smallest = results[results.smallest]['Returns'].groupby(level=0).mean()

R_highpb = results[results.highpb]['Returns'].groupby(level=0).mean()
R_lowpb = results[results.lowpb]['Returns'].groupby(level=0).mean()

R_top = results[results.top]['Returns'].groupby(level=0).mean()
R_bottom = results[results.bottom]['Returns'].groupby(level=0).mean()

# risk-free proxy
R_F = get_pricing('BIL', fields='price', start_date=start_date, end_date=end_date).pct_change()[1:]

# find it's beta against market
M = get_pricing('SPY', start_date=start_date, end_date=end_date, fields='price').pct_change()[1:]

# Defining our final factors
EXMRKT = M - R_F
SMB = R_smallest - R_biggest # small minus big
HML = R_highpb - R_lowpb # high minus low
MOM = R_top - R_bottom # momentum

# %% [markdown]
# Now that we've constructed our portfolios, let's look at our performance if we were to hold each one.

# %%
plt.plot(SMB.index, SMB.values)
plt.ylabel('Daily Percent Return')
plt.legend(['SMB Portfolio Returns']);

# %%
plt.plot(HML.index, HML.values)
plt.ylabel('Daily Percent Return')
plt.legend(['HML Portfolio Returns']);

# %%
plt.plot(MOM.index, MOM.values)
plt.ylabel('Daily Percent Return')
plt.legend(['MOM Portfolio Returns'])

# %% [markdown]
# Now, as we did in the CAPM lecture, we'll calculate the risk premia on each of these factors using the Fama-Macbeth regressions.

# %%
import numpy as np
import pandas as pd
import itertools
import statsmodels.api as sm
from statsmodels import regression,stats
import scipy

# %% [markdown]
# Our asset returns data is asset and date specific, whereas our factor portfolio returns are only date specific. Therefore, we'll need to spread each day's portfolio return across all the assets for which we have data for on that day.

# %%
data = results[['Returns']].set_index(results.index)
asset_list_sizes = [group[1].size for group in data.groupby(level=0)]

# Spreading the factor portfolio data across all assets for each day
SMB_column = [ [ SMB.loc[group[0]] ] * size for group, size in zip(data.groupby(level=0), asset_list_sizes)]
data['SMB'] = list(itertools.chain(*SMB_column))

HML_column = [ [ HML.loc[group[0]] ] * size for group, size in zip(data.groupby(level=0), asset_list_sizes)]
data['HML'] = list(itertools.chain(*HML_column))

MOM_column = [ [ MOM.loc[group[0]] ] * size for group, size in zip(data.groupby(level=0), asset_list_sizes)]
data['MOM'] = list(itertools.chain(*MOM_column))

EXMRKT_column = [ [EXMRKT.loc[group[0]]]*size if group[0] in EXMRKT.index else [None]*size for group, size in zip(data.groupby(level=0), asset_list_sizes)]
data['EXMRKT'] = list(itertools.chain(*EXMRKT_column))

data = sm.add_constant(data.dropna())

# Our list of assets from pipeline
assets = data.index.levels[1].unique()

# gathering our data to be asset-specific
Y = [data.xs(asset, level=1)['Returns'] for asset in assets] 
X = [data.xs(asset, level=1)[['EXMRKT','SMB', 'HML', 'MOM', 'const']] for asset in assets]

# First regression step: estimating the betas
reg_results = [regression.linear_model.OLS(y, x).fit().params for y, x in zip(Y, X) if not(x.empty or y.empty)]
indices = [asset for y, x, asset in zip(Y, X, assets) if not(x.empty or y.empty)]

betas = pd.DataFrame(reg_results, index=indices)
betas = sm.add_constant(betas.drop('const', axis=1))

R = data['Returns'].mean(axis=0, level=1)

# Second regression step: estimating the risk premia
risk_free_rate = np.mean(R_F)

final_results = regression.linear_model.OLS(R - risk_free_rate, betas).fit()

final_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Returns   R-squared:                       0.304
# Model:                            OLS   Adj. R-squared:                  0.303
# Method:                 Least Squares   F-statistic:                     183.8
# Date:                Wed, 05 Jul 2017   Prob (F-statistic):          1.01e-130
# Time:                        20:05:29   Log-Likelihood:                 7358.1
# No. Observations:                1686   AIC:                        -1.471e+04
# Df Residuals:                    1681   BIC:                        -1.468e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.0014      0.000     12.193      0.000         0.001     0.002
# EXMRKT         0.0039      0.000     19.352      0.000         0.004     0.004
# SMB           -0.0003   4.23e-05     -6.799      0.000        -0.000    -0.000
# HML        -3.911e-05   3.77e-05     -1.036      0.300        -0.000  3.49e-05
# MOM            0.0004   2.76e-05     13.004      0.000         0.000     0.000
# ==============================================================================
# Omnibus:                     1698.130   Durbin-Watson:                   2.051
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           186282.896
# Skew:                          -4.546   Prob(JB):                         0.00
# Kurtosis:                      53.686   Cond. No.                         8.94
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# #### Returns Prediction
# As discussed in the CAPM lecture, factor modeling can be used to predict future returns based on current fundamental factors. As well, it could be used to determine when an asset may be mispriced in order to arbitrage the difference, as shown in the CAPM lecture.
#
# Modeling future returns is accomplished by offsetting the returns in the regression, so that rather than predict for current returns, you are predicting for future returns. Once you have a predictive model, the most canonical way to create a strategy is to attempt a long-short equity approach.

# %% [markdown]
# ### Portfolio Construction for Hedging

# %% [markdown]
# Once we've determined that we are exposed to a factor, we may want to avoid depending on the performance of that factor by taking out a hedge. This is discussed in more detail in the Beta Hedging and Risk Factor Exposure lectures. The essential idea is to take the exposure your return stream has to a factor, and short the proportional value. So, if your total portfolio value was $V$, and the exposure you calculated to a certain factor return stream was $\beta$, you would short $\beta V$ amount of that return stream.
#
# The following is an example using the Fama-French factors we used before.

# %%
# we'll take a random sample of 500 assets from Q1500US in order to build a random portfolio
random_assets = list(np.random.choice(assets, size=500, replace=False))

portfolio_data = data[data.index.isin(random_assets, level=1)]

# this is the return of our portfolio with no hedging
R_portfolio_time_series = portfolio_data['Returns'].mean(level=0)

# %%
# next, we calculate the exposure of our portfolio to each of the Fama-French factors
portfolio_exposure = regression.linear_model.OLS(portfolio_data['Returns'], portfolio_data[['EXMRKT', 'SMB', 'HML', 'MOM', 'const']]).fit()

print portfolio_exposure.summary()

# our hedged return stream
hedged_portfolio = R_portfolio_time_series - \
                portfolio_exposure.params[0]*EXMRKT - \
                portfolio_exposure.params[1]*SMB - \
                portfolio_exposure.params[2]*HML - \
                portfolio_exposure.params[3]*MOM 

print 'Mean, Std of Hedged Portfolio:', np.mean(hedged_portfolio), np.std(hedged_portfolio)
print 'Mean, Std of Unhedged Portfolio:', np.mean(R_portfolio_time_series), np.std(R_portfolio_time_series)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Returns   R-squared:                       0.112
# Model:                            OLS   Adj. R-squared:                  0.112
# Method:                 Least Squares   F-statistic:                     3524.
# Date:                Wed, 05 Jul 2017   Prob (F-statistic):               0.00
# Time:                        20:05:29   Log-Likelihood:             2.6350e+05
# No. Observations:              111689   AIC:                        -5.270e+05
# Df Residuals:                  111684   BIC:                        -5.269e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# EXMRKT        -0.0883      0.008    -10.504      0.000        -0.105    -0.072
# SMB            2.2267      0.021    105.908      0.000         2.186     2.268
# HML            0.1535      0.024      6.339      0.000         0.106     0.201
# MOM            0.3942      0.059      6.718      0.000         0.279     0.509
# const          0.0004   6.91e-05      6.376      0.000         0.000     0.001
# ==============================================================================
# Omnibus:                    73190.344   Durbin-Watson:                   1.781
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         52262841.840
# Skew:                           1.805   Prob(JB):                         0.00
# Kurtosis:                     108.912   Cond. No.                         859.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Mean, Std of Hedged Portfolio: 0.000441881476173 0.00744896282751
# Mean, Std of Unhedged Portfolio: 0.000712804240589 0.0110269133391

# %% [markdown]
# Let's look at a graph of our two portfolio return streams

# %%
plt.plot(hedged_portfolio)
plt.plot(pd.DataFrame({'Hedged': hedged_portfolio.mean()}, index=hedged_portfolio.index))

plt.plot(R_portfolio_time_series)
plt.plot(pd.DataFrame({'Unhedged': R_portfolio_time_series.mean()}, index=R_portfolio_time_series.index))

plt.legend(['Hedged', 'Hedged Mean', 'Unhedged', 'Unhedged Mean'])

# %% [markdown]
# We'll check for normality, homoskedasticity, and autocorrelation in this model. For more information on the tests below, check out the [Violations of Regression Models](https://www.quantopian.com/lectures/violations-of-regression-models#notebook) lecture.

# %%
# testing for normality: jarque-bera
_, pvalue_JB, _, _ = stats.stattools.jarque_bera(portfolio_exposure.resid)
print "Jarque-Bera p-value: ", pvalue_JB

# testing for homoskedasticity: breush pagan
_, pvalue_BP, _, _ = stats.diagnostic.het_breushpagan(portfolio_exposure.resid, portfolio_data[['EXMRKT', 'SMB', 'HML', 'MOM', 'const']])
print "Breush Pagan p-value: ", pvalue_BP

# testing for autocorrelation
dw = stats.stattools.durbin_watson(portfolio_exposure.resid)
print "Durbin Watson statistic: ", dw
# Out:
# Jarque-Bera p-value:  0.0
# Breush Pagan p-value:  0.175817584465
# Durbin Watson statistic:  1.78140964293

# %% [markdown]
# ## Approach Two: Factor Value Normalization
#
# Another approach is to normalize factor values for each day and see how predictive of that day's returns they were. This is also known as cross-sectional factor analysis. We do this by computing a normalized factor value $b_{a,j}$ for each asset $a$ in the following way.
#
# $$b_{a,j} = \frac{F_{a,j} - \mu_{F_j}}{\sigma_{F_j}}$$
#
# $F_{a,j}$ is the value of factor $j$ for asset $a$ during this time, $\mu_{F_j}$ is the mean factor value across all assets, and $\sigma_{F_j}$ is the standard deviation of factor values over all assets. Notice that we are just computing a z-score to make asset specific factor values comparable across different factors.
#
# The exceptions to this formula are indicator variables, which are set to 1 for true and 0 for false. One example is industry membership: the coefficient tells us whether the asset belongs to the industry or not.
#
# After we calculate all of the normalized scores during time $t$, we can estimate factor $j$'s returns $F_{j,t}$, using a cross-sectional regression (i.e. at each time step, we perform a regression using the equations for all of the assets). Specifically, once we have returns for each asset $R_{a,t}$, and normalized factor coefficients $b_{a,j}$, we construct the following model and estimate the $F_j$s and $a_t$
#
# $$R_{a,t} = a_t + b_{a,F_1}F_1 + b_{a, F_2}F_2 + \dots + b_{a, F_K}F_K$$
#
# You can think of this as slicing through the other direction from the first analysis, as now the factor returns are unknowns to be solved for, whereas originally the coefficients were the unknowns. Another way to think about it is that you're determining how predictive of returns the factor was on that day, and therefore how much return you could have squeezed out of that factor.
#
# Following this procedure, we'll get the cross-sectional returns on 2016-11-22, and compute the coefficients for all assets:

# %% [markdown]
# We can take the fundamental data we got from the pipeline call above.

# %%
date = '2016-11-22'

BTP = results['book_to_price'][date]
z_score = (BTP - BTP.mean()) / BTP.std()
z_score.dropna(inplace=True)

plt.hist(z_score)
plt.xlabel('Z-Score')
plt.ylabel('Frequency')

# %% [markdown]
# #### Problem: The Data is Weirdly Distributed
# Notice how there are big outliers in the dataset that cause the z-scores to lose a lot of information. Basically the presence of some very large outliers causes the rest of the data to occupy a relatively small area. We can get around this issue using some data cleaning techniques, such as winsorization.
#
# #### Winsorization
# Winzorization takes the top $n\%$ of a dataset and sets it all equal to the least extreme value in the top $n\%$. For example, if your dataset ranged from 0-10, plus a few crazy outliers, those outliers would be set to 0 or 10 depending on their direction. The following is an example.

# %%
# Get some random data
random_data = np.random.normal(0, 1, 100)

# Put in some outliers
random_data[0] = 1000
random_data[1] = -1000

# Perform winsorization
print 'Before winsorization', np.min(random_data), np.max(random_data)
scipy.stats.mstats.winsorize(random_data, inplace=True, limits=0.01)
print 'After winsorization', np.min(random_data), np.max(random_data)
# Out:
# Before winsorization -1000.0 1000.0
# After winsorization -2.28498595696 1.99232987994

# %% [markdown]
# We'll apply the same technique to our data and grab the returns to all the assets in our universe. Then we'll run a linear regression to estimate $F_j$.

# %%
BTP = scipy.stats.mstats.winsorize(results['book_to_price'][date], limits=0.01)
BTP_z = (BTP - np.mean(BTP)) / np.std(BTP)

MC = scipy.stats.mstats.winsorize(results['market_cap'][date], limits=0.01)
MC_z = (MC - np.mean(MC)) / np.std(MC)

Lag_Ret = scipy.stats.mstats.winsorize(results['lagged_returns'][date], limits=0.01)
Lag_Ret_z = (Lag_Ret - np.mean(Lag_Ret)) / np.std(Lag_Ret)

returns = results['Returns'][date]

df_day = pd.DataFrame({'R': returns,
              'BTP_z': BTP_z,
              'MC_z': MC_z,
              'Lag_Ret_z': Lag_Ret_z,
              'Constant': 1}).dropna()

cross_sectional_results = regression.linear_model.OLS(df_day['R'], df_day[['BTP_z', 'MC_z', 'Lag_Ret_z', 'Constant']]).fit()

cross_sectional_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      R   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.140
# Date:                Wed, 05 Jul 2017   Prob (F-statistic):             0.0934
# Time:                        20:05:31   Log-Likelihood:                 3931.7
# No. Observations:                1489   AIC:                            -7855.
# Df Residuals:                    1485   BIC:                            -7834.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# BTP_z          0.0004      0.000      0.917      0.359        -0.000     0.001
# MC_z       -7.714e-05      0.000     -0.172      0.864        -0.001     0.001
# Lag_Ret_z     -0.0010      0.000     -2.309      0.021        -0.002    -0.000
# Constant       0.0073      0.000     16.329      0.000         0.006     0.008
# ==============================================================================
# Omnibus:                      504.248   Durbin-Watson:                   1.942
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            15522.766
# Skew:                           0.941   Prob(JB):                         0.00
# Kurtosis:                      18.705   Cond. No.                         1.09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# To expand this analysis, you would simply loop through days, running this every day and getting an estimated factor return.

# %% [markdown]
# *This presentation is for informational purposes only and does not constitute an offer to sell, a solicitation to buy, or a recommendation for any security; nor does it constitute an offer to provide investment advisory or other services by Quantopian, Inc. ("Quantopian"). Nothing contained herein constitutes investment advice or offers any opinion with respect to the suitability of any security, and any views expressed herein should not be taken as advice to buy, sell, or hold any security or as an endorsement of any security or company.  In preparing the information contained herein, Quantopian, Inc. has not taken into account the investment needs, objectives, and financial circumstances of any particular investor. Any views expressed and data illustrated herein were prepared based upon information, believed to be reliable, available to Quantopian, Inc. at the time of publication. Quantopian makes no guarantees as to their accuracy or completeness. All information is subject to change and may quickly become unreliable for various reasons, including changes in market conditions or economic circumstances.*
